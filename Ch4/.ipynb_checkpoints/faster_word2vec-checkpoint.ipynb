# %%
import sys
sys.path.append('..')
from common import config
# GPU에서 실행하기 위한 코드
#config.GPU = True
from common.np import *  # import cupy as np

# %%
class Embedding:
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.idx = None
    
    def forward(self, idx):
        W, = self.params
        self.idx = idx
        out = W[idx]
        return out
    
    def backward(self, dout):
        dW, = self.grads
        dw[...] = 0
        dW[self.idx] = dout # 좋지 않은 구현 방법
        return None

# %%
class Embedding:
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.idx = None

    def forward(self, idx):
        W, = self.params
        self.idx = idx
        out = W[idx] 
        return out

    def backward(self, dout):
        dW, = self.grads
        dW[...] = 0
        np.add.at(dW, self.idx, dout) # cpu는 numpy 일때, np.add.at(dW, self.idx, dout)
        return None

# %%
from common.layers import SigmoidWithLoss
import collections


class EmbeddingDot:
    def __init__(self, W):
        self.embed = Embedding(W)
        self.params = self.embed.params
        self.grads = self.embed.grads
        self.cache = None

    def forward(self, h, idx):
        target_W = self.embed.forward(idx)
        out = np.sum(target_W * h, axis=1)

        self.cache = (h, target_W)
        return out

    def backward(self, dout):
        h, target_W = self.cache
        dout = dout.reshape(dout.shape[0], 1)

        dtarget_W = dout * h
        self.embed.backward(dtarget_W)
        dh = dout * target_W
        return dh

# %%
class UnigramSampler:
    def __init__(self, corpus, power, sample_size):
        self.sample_size = sample_size
        self.vocab_size = None
        self.word_p = None

        counts = collections.Counter()
        for word_id in corpus:
            counts[word_id] += 1

        vocab_size = len(counts)
        self.vocab_size = vocab_size

        self.word_p = np.zeros(vocab_size)
        for i in range(vocab_size):
            self.word_p[i] = counts[i]

        self.word_p = np.power(self.word_p, power)
        self.word_p /= np.sum(self.word_p)

    def get_negative_sample(self, target):
        batch_size = target.shape[0]

        if not GPU:
            negative_sample = np.zeros((batch_size, self.sample_size), dtype=np.int32)

            for i in range(batch_size):
                p = self.word_p.copy()
                target_idx = target[i]
                p[target_idx] = 0
                p /= p.sum()
                negative_sample[i, :] = np.random.choice(self.vocab_size, size=self.sample_size, replace=False, p=p)
        else:
            # GPU(cupy）로 계산할 때는 속도를 우선한다.
            # 부정적 예에 타깃이 포함될 수 있다.
            negative_sample = np.random.choice(self.vocab_size, size=(batch_size, self.sample_size),
                                               replace=True, p=self.word_p)

        return negative_sample

# %%
class NegativeSamplingLoss:
    def __init__(self, W, corpus, power=0.75, sample_size=5):
        self.sample_size = sample_size
        self.sampler = UnigramSampler(corpus, power, sample_size)
        self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size + 1)]
        self.embed_dot_layers = [EmbeddingDot(W) for _ in range(sample_size + 1)]

        self.params, self.grads = [], []
        for layer in self.embed_dot_layers:
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, h, target):
        batch_size = target.shape[0]
        negative_sample = self.sampler.get_negative_sample(target)

        # 긍정적 예 순전파
        score = self.embed_dot_layers[0].forward(h, target)
        correct_label = np.ones(batch_size, dtype=np.int32)
        loss = self.loss_layers[0].forward(score, correct_label)

        # 부정적 예 순전파
        negative_label = np.zeros(batch_size, dtype=np.int32)
        for i in range(self.sample_size):
            negative_target = negative_sample[:, i]
            score = self.embed_dot_layers[1 + i].forward(h, negative_target)
            loss += self.loss_layers[1 + i].forward(score, negative_label)

        return loss

    def backward(self, dout=1):
        dh = 0
        for l0, l1 in zip(self.loss_layers, self.embed_dot_layers):
            dscore = l0.backward(dout)
            dh += l1.backward(dscore)

        return dh

# %%
import sys
sys.path.append('..')


class CBOW:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size

        # 가중치 초기화
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')

        # 계층 생성
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(W_in)  # Embedding 계층 사용
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)

        # 모든 가중치와 기울기를 배열에 모은다.
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 인스턴스 변수에 단어의 분산 표현을 저장한다.
        self.word_vecs = W_in

    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss

    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self.in_layers:
            layer.backward(dout)
        return None

# %%
import pickle
from common.trainer import Trainer
from common.optimizer import Adam
from common.util import create_contexts_target, to_cpu, to_gpu
from dataset import ptb

# 하이퍼파라미터 설정
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 10

# 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU:
    contexts, target = to_gpu(contexts), to_gpu(target)
    
# 모델 등 생성
model = CBOW(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중에 사용할 수 있도록 필요한 데이터 저장
word_vecs = model.word_vecs
if config.GPU:
    word_vecs = to_cpu(word_vecs)
params = {}
params['word_vecs'] = word_vecs.astype(np.float16)
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word
pkl_file = 'cbow_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | 에폭 1 |  반복 1 / 9295 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 21 / 9295 | 시간 1[s] | 손실 4.16
# | 에폭 1 |  반복 41 / 9295 | 시간 2[s] | 손실 4.15
# | 에폭 1 |  반복 61 / 9295 | 시간 4[s] | 손실 4.12
# | 에폭 1 |  반복 81 / 9295 | 시간 5[s] | 손실 4.05
# | 에폭 1 |  반복 101 / 9295 | 시간 6[s] | 손실 3.92
# | 에폭 1 |  반복 121 / 9295 | 시간 8[s] | 손실 3.78
# | 에폭 1 |  반복 141 / 9295 | 시간 9[s] | 손실 3.63
# | 에폭 1 |  반복 161 / 9295 | 시간 10[s] | 손실 3.49
# | 에폭 1 |  반복 181 / 9295 | 시간 12[s] | 손실 3.36
# | 에폭 1 |  반복 201 / 9295 | 시간 13[s] | 손실 3.25
# | 에폭 1 |  반복 221 / 9295 | 시간 15[s] | 손실 3.17
# | 에폭 1 |  반복 241 / 9295 | 시간 16[s] | 손실 3.07
# | 에폭 1 |  반복 261 / 9295 | 시간 17[s] | 손실 3.00
# | 에폭 1 |  반복 281 / 9295 | 시간 19[s] | 손실 2.95
# | 에폭 1 |  반복 301 / 9295 | 시간 20[s] | 손실 2.91
# | 에폭 1 |  반복 321 / 9295 | 시간 21[s] | 손실 2.88
# | 에폭 1 |  반복 341 / 9295 | 시간 23[s] | 손실 2.83
# | 에폭 1 |  반복 361 / 9295 | 시간 24[s] | 손실 2.81
# | 에폭 1 |  반복 381 / 9295 | 시간 25[s] | 손실 2.79
# | 에폭 1 |  반복 401 / 9295 | 시간 27[s] | 손실 2.77
# | 에폭 1 |  반복 421 / 9295 | 시간 28[s] | 손실 2.74
# | 에폭 1 |  반복 441 / 9295 | 시간 29[s] | 손실 2.73
# | 에폭 1 |  반복 461 / 9295 | 시간 31[s] | 손실 2.71
# | 에폭 1 |  반복 481 / 9295 | 시간 32[s] | 손실 2.71
# | 에폭 1 |  반복 501 / 9295 | 시간 33[s] | 손실 2.69
# | 에폭 1 |  반복 521 / 9295 | 시간 35[s] | 손실 2.71
# | 에폭 1 |  반복 541 / 9295 | 시간 36[s] | 손실 2.66
# | 에폭 1 |  반복 561 / 9295 | 시간 38[s] | 손실 2.67
# | 에폭 1 |  반복 581 / 9295 | 시간 39[s] | 손실 2.62
# | 에폭 1 |  반복 601 / 9295 | 시간 40[s] | 손실 2.63
# | 에폭 1 |  반복 621 / 9295 | 시간 42[s] | 손실 2.64
# | 에폭 1 |  반복 641 / 9295 | 시간 43[s] | 손실 2.62
# | 에폭 1 |  반복 661 / 9295 | 시간 44[s] | 손실 2.61
# | 에폭 1 |  반복 681 / 9295 | 시간 46[s] | 손실 2.62
# | 에폭 1 |  반복 701 / 9295 | 시간 47[s] | 손실 2.62
# | 에폭 1 |  반복 721 / 9295 | 시간 48[s] | 손실 2.61
# | 에폭 1 |  반복 741 / 9295 | 시간 50[s] | 손실 2.62
# | 에폭 1 |  반복 761 / 9295 | 시간 51[s] | 손실 2.59
# | 에폭 1 |  반복 781 / 9295 | 시간 52[s] | 손실 2.59
# | 에폭 1 |  반복 801 / 9295 | 시간 54[s] | 손실 2.59
# | 에폭 1 |  반복 821 / 9295 | 시간 55[s] | 손실 2.58
# | 에폭 1 |  반복 841 / 9295 | 시간 56[s] | 손실 2.58
# | 에폭 1 |  반복 861 / 9295 | 시간 58[s] | 손실 2.58
# | 에폭 1 |  반복 881 / 9295 | 시간 59[s] | 손실 2.54
# | 에폭 1 |  반복 901 / 9295 | 시간 61[s] | 손실 2.57
# | 에폭 1 |  반복 921 / 9295 | 시간 62[s] | 손실 2.55
# | 에폭 1 |  반복 941 / 9295 | 시간 63[s] | 손실 2.57
# | 에폭 1 |  반복 961 / 9295 | 시간 65[s] | 손실 2.54
# | 에폭 1 |  반복 981 / 9295 | 시간 66[s] | 손실 2.58
# | 에폭 1 |  반복 1001 / 9295 | 시간 67[s] | 손실 2.56
# | 에폭 1 |  반복 1021 / 9295 | 시간 69[s] | 손실 2.56
# | 에폭 1 |  반복 1041 / 9295 | 시간 70[s] | 손실 2.54
# | 에폭 1 |  반복 1061 / 9295 | 시간 71[s] | 손실 2.57
# | 에폭 1 |  반복 1081 / 9295 | 시간 73[s] | 손실 2.54
# | 에폭 1 |  반복 1101 / 9295 | 시간 74[s] | 손실 2.56
# | 에폭 1 |  반복 1121 / 9295 | 시간 75[s] | 손실 2.56
# | 에폭 1 |  반복 1141 / 9295 | 시간 77[s] | 손실 2.53
# | 에폭 1 |  반복 1161 / 9295 | 시간 78[s] | 손실 2.54
# | 에폭 1 |  반복 1181 / 9295 | 시간 79[s] | 손실 2.51
# | 에폭 1 |  반복 1201 / 9295 | 시간 81[s] | 손실 2.52
# | 에폭 1 |  반복 1221 / 9295 | 시간 82[s] | 손실 2.54
# | 에폭 1 |  반복 1241 / 9295 | 시간 84[s] | 손실 2.54
# | 에폭 1 |  반복 1261 / 9295 | 시간 85[s] | 손실 2.54
# | 에폭 1 |  반복 1281 / 9295 | 시간 86[s] | 손실 2.52
# | 에폭 1 |  반복 1301 / 9295 | 시간 88[s] | 손실 2.52
# | 에폭 1 |  반복 1321 / 9295 | 시간 89[s] | 손실 2.51
# | 에폭 1 |  반복 1341 / 9295 | 시간 90[s] | 손실 2.52
# | 에폭 1 |  반복 1361 / 9295 | 시간 92[s] | 손실 2.50
# | 에폭 1 |  반복 1381 / 9295 | 시간 93[s] | 손실 2.52
# | 에폭 1 |  반복 1401 / 9295 | 시간 94[s] | 손실 2.51
# | 에폭 1 |  반복 1421 / 9295 | 시간 96[s] | 손실 2.51
# | 에폭 1 |  반복 1441 / 9295 | 시간 97[s] | 손실 2.50
# | 에폭 1 |  반복 1461 / 9295 | 시간 98[s] | 손실 2.52
# | 에폭 1 |  반복 1481 / 9295 | 시간 100[s] | 손실 2.52
# | 에폭 1 |  반복 1501 / 9295 | 시간 101[s] | 손실 2.53
# | 에폭 1 |  반복 1521 / 9295 | 시간 103[s] | 손실 2.52
# | 에폭 1 |  반복 1541 / 9295 | 시간 104[s] | 손실 2.52
# | 에폭 1 |  반복 1561 / 9295 | 시간 105[s] | 손실 2.51
# | 에폭 1 |  반복 1581 / 9295 | 시간 107[s] | 손실 2.54
# | 에폭 1 |  반복 1601 / 9295 | 시간 108[s] | 손실 2.48
# | 에폭 1 |  반복 1621 / 9295 | 시간 109[s] | 손실 2.48
# | 에폭 1 |  반복 1641 / 9295 | 시간 111[s] | 손실 2.47
# | 에폭 1 |  반복 1661 / 9295 | 시간 112[s] | 손실 2.48
# | 에폭 1 |  반복 1681 / 9295 | 시간 113[s] | 손실 2.51
# | 에폭 1 |  반복 1701 / 9295 | 시간 115[s] | 손실 2.52
# | 에폭 1 |  반복 1721 / 9295 | 시간 116[s] | 손실 2.50
# | 에폭 1 |  반복 1741 / 9295 | 시간 117[s] | 손실 2.49
# | 에폭 1 |  반복 1761 / 9295 | 시간 119[s] | 손실 2.48
# | 에폭 1 |  반복 1781 / 9295 | 시간 120[s] | 손실 2.49
# | 에폭 1 |  반복 1801 / 9295 | 시간 122[s] | 손실 2.49
# | 에폭 1 |  반복 1821 / 9295 | 시간 123[s] | 손실 2.52
# | 에폭 1 |  반복 1841 / 9295 | 시간 124[s] | 손실 2.50
# | 에폭 1 |  반복 1861 / 9295 | 시간 126[s] | 손실 2.49
# | 에폭 1 |  반복 1881 / 9295 | 시간 127[s] | 손실 2.51
# | 에폭 1 |  반복 1901 / 9295 | 시간 128[s] | 손실 2.48
# | 에폭 1 |  반복 1921 / 9295 | 시간 130[s] | 손실 2.51
# | 에폭 1 |  반복 1941 / 9295 | 시간 131[s] | 손실 2.46
# | 에폭 1 |  반복 1961 / 9295 | 시간 132[s] | 손실 2.50
# | 에폭 1 |  반복 1981 / 9295 | 시간 134[s] | 손실 2.49
# | 에폭 1 |  반복 2001 / 9295 | 시간 135[s] | 손실 2.49
# | 에폭 1 |  반복 2021 / 9295 | 시간 136[s] | 손실 2.49
# | 에폭 1 |  반복 2041 / 9295 | 시간 138[s] | 손실 2.48
# | 에폭 1 |  반복 2061 / 9295 | 시간 139[s] | 손실 2.48
# | 에폭 1 |  반복 2081 / 9295 | 시간 140[s] | 손실 2.49
# | 에폭 1 |  반복 2101 / 9295 | 시간 142[s] | 손실 2.52
# | 에폭 1 |  반복 2121 / 9295 | 시간 143[s] | 손실 2.47
# | 에폭 1 |  반복 2141 / 9295 | 시간 145[s] | 손실 2.50
# | 에폭 1 |  반복 2161 / 9295 | 시간 146[s] | 손실 2.52
# | 에폭 1 |  반복 2181 / 9295 | 시간 147[s] | 손실 2.48
# | 에폭 1 |  반복 2201 / 9295 | 시간 149[s] | 손실 2.48
# | 에폭 1 |  반복 2221 / 9295 | 시간 150[s] | 손실 2.46
# | 에폭 1 |  반복 2241 / 9295 | 시간 151[s] | 손실 2.46
# | 에폭 1 |  반복 2261 / 9295 | 시간 153[s] | 손실 2.48
# | 에폭 1 |  반복 2281 / 9295 | 시간 154[s] | 손실 2.51
# | 에폭 1 |  반복 2301 / 9295 | 시간 155[s] | 손실 2.51
# | 에폭 1 |  반복 2321 / 9295 | 시간 157[s] | 손실 2.48
# | 에폭 1 |  반복 2341 / 9295 | 시간 158[s] | 손실 2.49
# | 에폭 1 |  반복 2361 / 9295 | 시간 159[s] | 손실 2.47
# | 에폭 1 |  반복 2381 / 9295 | 시간 161[s] | 손실 2.45
# | 에폭 1 |  반복 2401 / 9295 | 시간 162[s] | 손실 2.47
# | 에폭 1 |  반복 2421 / 9295 | 시간 164[s] | 손실 2.47
# | 에폭 1 |  반복 2441 / 9295 | 시간 165[s] | 손실 2.49
# | 에폭 1 |  반복 2461 / 9295 | 시간 166[s] | 손실 2.46
# | 에폭 1 |  반복 2481 / 9295 | 시간 168[s] | 손실 2.50
# | 에폭 1 |  반복 2501 / 9295 | 시간 169[s] | 손실 2.50
# | 에폭 1 |  반복 2521 / 9295 | 시간 170[s] | 손실 2.46
# | 에폭 1 |  반복 2541 / 9295 | 시간 172[s] | 손실 2.46
# | 에폭 1 |  반복 2561 / 9295 | 시간 173[s] | 손실 2.50
# | 에폭 1 |  반복 2581 / 9295 | 시간 174[s] | 손실 2.48
# | 에폭 1 |  반복 2601 / 9295 | 시간 176[s] | 손실 2.46
# | 에폭 1 |  반복 2621 / 9295 | 시간 177[s] | 손실 2.48
# | 에폭 1 |  반복 2641 / 9295 | 시간 178[s] | 손실 2.50
# | 에폭 1 |  반복 2661 / 9295 | 시간 180[s] | 손실 2.47
# | 에폭 1 |  반복 2681 / 9295 | 시간 181[s] | 손실 2.47
# | 에폭 1 |  반복 2701 / 9295 | 시간 183[s] | 손실 2.47
# | 에폭 1 |  반복 2721 / 9295 | 시간 184[s] | 손실 2.47
# | 에폭 1 |  반복 2741 / 9295 | 시간 185[s] | 손실 2.44
# | 에폭 1 |  반복 2761 / 9295 | 시간 187[s] | 손실 2.46
# | 에폭 1 |  반복 2781 / 9295 | 시간 188[s] | 손실 2.46
# | 에폭 1 |  반복 2801 / 9295 | 시간 189[s] | 손실 2.48
# | 에폭 1 |  반복 2821 / 9295 | 시간 191[s] | 손실 2.47
# | 에폭 1 |  반복 2841 / 9295 | 시간 192[s] | 손실 2.42
# | 에폭 1 |  반복 2861 / 9295 | 시간 193[s] | 손실 2.47
# | 에폭 1 |  반복 2881 / 9295 | 시간 195[s] | 손실 2.45
# | 에폭 1 |  반복 2901 / 9295 | 시간 196[s] | 손실 2.44
# | 에폭 1 |  반복 2921 / 9295 | 시간 197[s] | 손실 2.46
# | 에폭 1 |  반복 2941 / 9295 | 시간 199[s] | 손실 2.46
# | 에폭 1 |  반복 2961 / 9295 | 시간 200[s] | 손실 2.47
# | 에폭 1 |  반복 2981 / 9295 | 시간 202[s] | 손실 2.48
# | 에폭 1 |  반복 3001 / 9295 | 시간 203[s] | 손실 2.47
# | 에폭 1 |  반복 3021 / 9295 | 시간 204[s] | 손실 2.45
# | 에폭 1 |  반복 3041 / 9295 | 시간 206[s] | 손실 2.44
# | 에폭 1 |  반복 3061 / 9295 | 시간 207[s] | 손실 2.45
# | 에폭 1 |  반복 3081 / 9295 | 시간 208[s] | 손실 2.42
# | 에폭 1 |  반복 3101 / 9295 | 시간 210[s] | 손실 2.43
# | 에폭 1 |  반복 3121 / 9295 | 시간 211[s] | 손실 2.48
# | 에폭 1 |  반복 3141 / 9295 | 시간 212[s] | 손실 2.46
# | 에폭 1 |  반복 3161 / 9295 | 시간 214[s] | 손실 2.45
# | 에폭 1 |  반복 3181 / 9295 | 시간 215[s] | 손실 2.45
# | 에폭 1 |  반복 3201 / 9295 | 시간 216[s] | 손실 2.46
# | 에폭 1 |  반복 3221 / 9295 | 시간 218[s] | 손실 2.45
# | 에폭 1 |  반복 3241 / 9295 | 시간 219[s] | 손실 2.46
# | 에폭 1 |  반복 3261 / 9295 | 시간 221[s] | 손실 2.45
# | 에폭 1 |  반복 3281 / 9295 | 시간 222[s] | 손실 2.43
# | 에폭 1 |  반복 3301 / 9295 | 시간 223[s] | 손실 2.41
# | 에폭 1 |  반복 3321 / 9295 | 시간 225[s] | 손실 2.42
# | 에폭 1 |  반복 3341 / 9295 | 시간 226[s] | 손실 2.44
# | 에폭 1 |  반복 3361 / 9295 | 시간 227[s] | 손실 2.45
# | 에폭 1 |  반복 3381 / 9295 | 시간 229[s] | 손실 2.40
# | 에폭 1 |  반복 3401 / 9295 | 시간 230[s] | 손실 2.42
# | 에폭 1 |  반복 3421 / 9295 | 시간 231[s] | 손실 2.42
# | 에폭 1 |  반복 3441 / 9295 | 시간 233[s] | 손실 2.45
# | 에폭 1 |  반복 3461 / 9295 | 시간 234[s] | 손실 2.42
# | 에폭 1 |  반복 3481 / 9295 | 시간 235[s] | 손실 2.41
# | 에폭 1 |  반복 3501 / 9295 | 시간 237[s] | 손실 2.43
# | 에폭 1 |  반복 3521 / 9295 | 시간 238[s] | 손실 2.40
# | 에폭 1 |  반복 3541 / 9295 | 시간 240[s] | 손실 2.46
# | 에폭 1 |  반복 3561 / 9295 | 시간 241[s] | 손실 2.42
# | 에폭 1 |  반복 3581 / 9295 | 시간 242[s] | 손실 2.44
# | 에폭 1 |  반복 3601 / 9295 | 시간 244[s] | 손실 2.43
# | 에폭 1 |  반복 3621 / 9295 | 시간 245[s] | 손실 2.43
# | 에폭 1 |  반복 3641 / 9295 | 시간 246[s] | 손실 2.45
# | 에폭 1 |  반복 3661 / 9295 | 시간 248[s] | 손실 2.43
# | 에폭 1 |  반복 3681 / 9295 | 시간 249[s] | 손실 2.40
# | 에폭 1 |  반복 3701 / 9295 | 시간 250[s] | 손실 2.44
# | 에폭 1 |  반복 3721 / 9295 | 시간 252[s] | 손실 2.41
# | 에폭 1 |  반복 3741 / 9295 | 시간 253[s] | 손실 2.44
# | 에폭 1 |  반복 3761 / 9295 | 시간 254[s] | 손실 2.39
# | 에폭 1 |  반복 3781 / 9295 | 시간 256[s] | 손실 2.41
# | 에폭 1 |  반복 3801 / 9295 | 시간 257[s] | 손실 2.40
# | 에폭 1 |  반복 3821 / 9295 | 시간 258[s] | 손실 2.40
# | 에폭 1 |  반복 3841 / 9295 | 시간 260[s] | 손실 2.44
# | 에폭 1 |  반복 3861 / 9295 | 시간 261[s] | 손실 2.39
# | 에폭 1 |  반복 3881 / 9295 | 시간 263[s] | 손실 2.40
# | 에폭 1 |  반복 3901 / 9295 | 시간 264[s] | 손실 2.41
# | 에폭 1 |  반복 3921 / 9295 | 시간 265[s] | 손실 2.43
# | 에폭 1 |  반복 3941 / 9295 | 시간 267[s] | 손실 2.40
# | 에폭 1 |  반복 3961 / 9295 | 시간 268[s] | 손실 2.38
# | 에폭 1 |  반복 3981 / 9295 | 시간 269[s] | 손실 2.37
# | 에폭 1 |  반복 4001 / 9295 | 시간 271[s] | 손실 2.44
# | 에폭 1 |  반복 4021 / 9295 | 시간 272[s] | 손실 2.38
# | 에폭 1 |  반복 4041 / 9295 | 시간 273[s] | 손실 2.43
# | 에폭 1 |  반복 4061 / 9295 | 시간 275[s] | 손실 2.38
# | 에폭 1 |  반복 4081 / 9295 | 시간 276[s] | 손실 2.43
# | 에폭 1 |  반복 4101 / 9295 | 시간 277[s] | 손실 2.44
# | 에폭 1 |  반복 4121 / 9295 | 시간 279[s] | 손실 2.38
# | 에폭 1 |  반복 4141 / 9295 | 시간 280[s] | 손실 2.39
# | 에폭 1 |  반복 4161 / 9295 | 시간 282[s] | 손실 2.43
# | 에폭 1 |  반복 4181 / 9295 | 시간 283[s] | 손실 2.37
# | 에폭 1 |  반복 4201 / 9295 | 시간 284[s] | 손실 2.37
# | 에폭 1 |  반복 4221 / 9295 | 시간 286[s] | 손실 2.37
# | 에폭 1 |  반복 4241 / 9295 | 시간 287[s] | 손실 2.40
# | 에폭 1 |  반복 4261 / 9295 | 시간 288[s] | 손실 2.40
# | 에폭 1 |  반복 4281 / 9295 | 시간 290[s] | 손실 2.39
# | 에폭 1 |  반복 4301 / 9295 | 시간 291[s] | 손실 2.39
# | 에폭 1 |  반복 4321 / 9295 | 시간 292[s] | 손실 2.39
# | 에폭 1 |  반복 4341 / 9295 | 시간 294[s] | 손실 2.36
# | 에폭 1 |  반복 4361 / 9295 | 시간 295[s] | 손실 2.37
# | 에폭 1 |  반복 4381 / 9295 | 시간 296[s] | 손실 2.33
# | 에폭 1 |  반복 4401 / 9295 | 시간 298[s] | 손실 2.36
# | 에폭 1 |  반복 4421 / 9295 | 시간 299[s] | 손실 2.38
# | 에폭 1 |  반복 4441 / 9295 | 시간 301[s] | 손실 2.41
# | 에폭 1 |  반복 4461 / 9295 | 시간 302[s] | 손실 2.38
# | 에폭 1 |  반복 4481 / 9295 | 시간 303[s] | 손실 2.35
# | 에폭 1 |  반복 4501 / 9295 | 시간 305[s] | 손실 2.38
# | 에폭 1 |  반복 4521 / 9295 | 시간 306[s] | 손실 2.37
# | 에폭 1 |  반복 4541 / 9295 | 시간 307[s] | 손실 2.40
# | 에폭 1 |  반복 4561 / 9295 | 시간 309[s] | 손실 2.38
# | 에폭 1 |  반복 4581 / 9295 | 시간 310[s] | 손실 2.35
# | 에폭 1 |  반복 4601 / 9295 | 시간 312[s] | 손실 2.36
# | 에폭 1 |  반복 4621 / 9295 | 시간 313[s] | 손실 2.42
# | 에폭 1 |  반복 4641 / 9295 | 시간 314[s] | 손실 2.38
# | 에폭 1 |  반복 4661 / 9295 | 시간 316[s] | 손실 2.35
# | 에폭 1 |  반복 4681 / 9295 | 시간 317[s] | 손실 2.38
# | 에폭 1 |  반복 4701 / 9295 | 시간 318[s] | 손실 2.38
# | 에폭 1 |  반복 4721 / 9295 | 시간 320[s] | 손실 2.34
# | 에폭 1 |  반복 4741 / 9295 | 시간 321[s] | 손실 2.37
# | 에폭 1 |  반복 4761 / 9295 | 시간 322[s] | 손실 2.38
# | 에폭 1 |  반복 4781 / 9295 | 시간 324[s] | 손실 2.36
# | 에폭 1 |  반복 4801 / 9295 | 시간 325[s] | 손실 2.36
# | 에폭 1 |  반복 4821 / 9295 | 시간 326[s] | 손실 2.36
# | 에폭 1 |  반복 4841 / 9295 | 시간 328[s] | 손실 2.34
# | 에폭 1 |  반복 4861 / 9295 | 시간 329[s] | 손실 2.33
# | 에폭 1 |  반복 4881 / 9295 | 시간 331[s] | 손실 2.38
# | 에폭 1 |  반복 4901 / 9295 | 시간 332[s] | 손실 2.34
# | 에폭 1 |  반복 4921 / 9295 | 시간 333[s] | 손실 2.34
# | 에폭 1 |  반복 4941 / 9295 | 시간 335[s] | 손실 2.38
# | 에폭 1 |  반복 4961 / 9295 | 시간 336[s] | 손실 2.35
# | 에폭 1 |  반복 4981 / 9295 | 시간 337[s] | 손실 2.36
# | 에폭 1 |  반복 5001 / 9295 | 시간 339[s] | 손실 2.37
# | 에폭 1 |  반복 5021 / 9295 | 시간 340[s] | 손실 2.39
# | 에폭 1 |  반복 5041 / 9295 | 시간 341[s] | 손실 2.37
# | 에폭 1 |  반복 5061 / 9295 | 시간 343[s] | 손실 2.36
# | 에폭 1 |  반복 5081 / 9295 | 시간 344[s] | 손실 2.38
# | 에폭 1 |  반복 5101 / 9295 | 시간 345[s] | 손실 2.38
# | 에폭 1 |  반복 5121 / 9295 | 시간 347[s] | 손실 2.38
# | 에폭 1 |  반복 5141 / 9295 | 시간 348[s] | 손실 2.36
# | 에폭 1 |  반복 5161 / 9295 | 시간 350[s] | 손실 2.37
# | 에폭 1 |  반복 5181 / 9295 | 시간 351[s] | 손실 2.37
# | 에폭 1 |  반복 5201 / 9295 | 시간 352[s] | 손실 2.37
# | 에폭 1 |  반복 5221 / 9295 | 시간 354[s] | 손실 2.35
# | 에폭 1 |  반복 5241 / 9295 | 시간 355[s] | 손실 2.35
# | 에폭 1 |  반복 5261 / 9295 | 시간 356[s] | 손실 2.35
# | 에폭 1 |  반복 5281 / 9295 | 시간 358[s] | 손실 2.32
# | 에폭 1 |  반복 5301 / 9295 | 시간 359[s] | 손실 2.38
# | 에폭 1 |  반복 5321 / 9295 | 시간 360[s] | 손실 2.36
# | 에폭 1 |  반복 5341 / 9295 | 시간 362[s] | 손실 2.34
# | 에폭 1 |  반복 5361 / 9295 | 시간 363[s] | 손실 2.35
# | 에폭 1 |  반복 5381 / 9295 | 시간 364[s] | 손실 2.36
# | 에폭 1 |  반복 5401 / 9295 | 시간 366[s] | 손실 2.36
# | 에폭 1 |  반복 5421 / 9295 | 시간 367[s] | 손실 2.32
# | 에폭 1 |  반복 5441 / 9295 | 시간 369[s] | 손실 2.34
# | 에폭 1 |  반복 5461 / 9295 | 시간 370[s] | 손실 2.36
# | 에폭 1 |  반복 5481 / 9295 | 시간 371[s] | 손실 2.34
# | 에폭 1 |  반복 5501 / 9295 | 시간 373[s] | 손실 2.34
# | 에폭 1 |  반복 5521 / 9295 | 시간 374[s] | 손실 2.36
# | 에폭 1 |  반복 5541 / 9295 | 시간 375[s] | 손실 2.35
# | 에폭 1 |  반복 5561 / 9295 | 시간 377[s] | 손실 2.35
# | 에폭 1 |  반복 5581 / 9295 | 시간 378[s] | 손실 2.34
# | 에폭 1 |  반복 5601 / 9295 | 시간 379[s] | 손실 2.32
# | 에폭 1 |  반복 5621 / 9295 | 시간 381[s] | 손실 2.32
# | 에폭 1 |  반복 5641 / 9295 | 시간 382[s] | 손실 2.36
# | 에폭 1 |  반복 5661 / 9295 | 시간 383[s] | 손실 2.33
# | 에폭 1 |  반복 5681 / 9295 | 시간 385[s] | 손실 2.35
# | 에폭 1 |  반복 5701 / 9295 | 시간 386[s] | 손실 2.35
# | 에폭 1 |  반복 5721 / 9295 | 시간 388[s] | 손실 2.33
# | 에폭 1 |  반복 5741 / 9295 | 시간 389[s] | 손실 2.31
# | 에폭 1 |  반복 5761 / 9295 | 시간 390[s] | 손실 2.35
# | 에폭 1 |  반복 5781 / 9295 | 시간 392[s] | 손실 2.33
# | 에폭 1 |  반복 5801 / 9295 | 시간 393[s] | 손실 2.30
# | 에폭 1 |  반복 5821 / 9295 | 시간 394[s] | 손실 2.34
# | 에폭 1 |  반복 5841 / 9295 | 시간 396[s] | 손실 2.33
# | 에폭 1 |  반복 5861 / 9295 | 시간 397[s] | 손실 2.33
# | 에폭 1 |  반복 5881 / 9295 | 시간 398[s] | 손실 2.31
# | 에폭 1 |  반복 5901 / 9295 | 시간 400[s] | 손실 2.35
# | 에폭 1 |  반복 5921 / 9295 | 시간 401[s] | 손실 2.31
# | 에폭 1 |  반복 5941 / 9295 | 시간 402[s] | 손실 2.32
# | 에폭 1 |  반복 5961 / 9295 | 시간 404[s] | 손실 2.30
# | 에폭 1 |  반복 5981 / 9295 | 시간 405[s] | 손실 2.32
# | 에폭 1 |  반복 6001 / 9295 | 시간 407[s] | 손실 2.33
# | 에폭 1 |  반복 6021 / 9295 | 시간 408[s] | 손실 2.33
# | 에폭 1 |  반복 6041 / 9295 | 시간 409[s] | 손실 2.30
# | 에폭 1 |  반복 6061 / 9295 | 시간 411[s] | 손실 2.32
# | 에폭 1 |  반복 6081 / 9295 | 시간 412[s] | 손실 2.33
# | 에폭 1 |  반복 6101 / 9295 | 시간 413[s] | 손실 2.36
# | 에폭 1 |  반복 6121 / 9295 | 시간 415[s] | 손실 2.32
# | 에폭 1 |  반복 6141 / 9295 | 시간 416[s] | 손실 2.30
# | 에폭 1 |  반복 6161 / 9295 | 시간 417[s] | 손실 2.33
# | 에폭 1 |  반복 6181 / 9295 | 시간 419[s] | 손실 2.34
# | 에폭 1 |  반복 6201 / 9295 | 시간 420[s] | 손실 2.32
# | 에폭 1 |  반복 6221 / 9295 | 시간 421[s] | 손실 2.31
# | 에폭 1 |  반복 6241 / 9295 | 시간 423[s] | 손실 2.37
# | 에폭 1 |  반복 6261 / 9295 | 시간 424[s] | 손실 2.30
# | 에폭 1 |  반복 6281 / 9295 | 시간 426[s] | 손실 2.32
# | 에폭 1 |  반복 6301 / 9295 | 시간 427[s] | 손실 2.29
# | 에폭 1 |  반복 6321 / 9295 | 시간 428[s] | 손실 2.30
# | 에폭 1 |  반복 6341 / 9295 | 시간 430[s] | 손실 2.31
# | 에폭 1 |  반복 6361 / 9295 | 시간 431[s] | 손실 2.33
# | 에폭 1 |  반복 6381 / 9295 | 시간 432[s] | 손실 2.31
# | 에폭 1 |  반복 6401 / 9295 | 시간 434[s] | 손실 2.28
# | 에폭 1 |  반복 6421 / 9295 | 시간 435[s] | 손실 2.31
# | 에폭 1 |  반복 6441 / 9295 | 시간 436[s] | 손실 2.32
# | 에폭 1 |  반복 6461 / 9295 | 시간 438[s] | 손실 2.30
# | 에폭 1 |  반복 6481 / 9295 | 시간 439[s] | 손실 2.30
# | 에폭 1 |  반복 6501 / 9295 | 시간 440[s] | 손실 2.32
# | 에폭 1 |  반복 6521 / 9295 | 시간 442[s] | 손실 2.29
# | 에폭 1 |  반복 6541 / 9295 | 시간 443[s] | 손실 2.34
# | 에폭 1 |  반복 6561 / 9295 | 시간 444[s] | 손실 2.31
# | 에폭 1 |  반복 6581 / 9295 | 시간 446[s] | 손실 2.32
# | 에폭 1 |  반복 6601 / 9295 | 시간 447[s] | 손실 2.29
# | 에폭 1 |  반복 6621 / 9295 | 시간 449[s] | 손실 2.33
# | 에폭 1 |  반복 6641 / 9295 | 시간 450[s] | 손실 2.31
# | 에폭 1 |  반복 6661 / 9295 | 시간 451[s] | 손실 2.29
# | 에폭 1 |  반복 6681 / 9295 | 시간 453[s] | 손실 2.31
# | 에폭 1 |  반복 6701 / 9295 | 시간 454[s] | 손실 2.30
# | 에폭 1 |  반복 6721 / 9295 | 시간 455[s] | 손실 2.31
# | 에폭 1 |  반복 6741 / 9295 | 시간 457[s] | 손실 2.28
# | 에폭 1 |  반복 6761 / 9295 | 시간 458[s] | 손실 2.30
# | 에폭 1 |  반복 6781 / 9295 | 시간 459[s] | 손실 2.27
# | 에폭 1 |  반복 6801 / 9295 | 시간 461[s] | 손실 2.29
# | 에폭 1 |  반복 6821 / 9295 | 시간 462[s] | 손실 2.32
# | 에폭 1 |  반복 6841 / 9295 | 시간 463[s] | 손실 2.30
# | 에폭 1 |  반복 6861 / 9295 | 시간 465[s] | 손실 2.32
# | 에폭 1 |  반복 6881 / 9295 | 시간 466[s] | 손실 2.29
# | 에폭 1 |  반복 6901 / 9295 | 시간 468[s] | 손실 2.28
# | 에폭 1 |  반복 6921 / 9295 | 시간 469[s] | 손실 2.27
# | 에폭 1 |  반복 6941 / 9295 | 시간 470[s] | 손실 2.30
# | 에폭 1 |  반복 6961 / 9295 | 시간 472[s] | 손실 2.27
# | 에폭 1 |  반복 6981 / 9295 | 시간 473[s] | 손실 2.30
# | 에폭 1 |  반복 7001 / 9295 | 시간 474[s] | 손실 2.30
# | 에폭 1 |  반복 7021 / 9295 | 시간 476[s] | 손실 2.26
# | 에폭 1 |  반복 7041 / 9295 | 시간 477[s] | 손실 2.28
# | 에폭 1 |  반복 7061 / 9295 | 시간 478[s] | 손실 2.27
# | 에폭 1 |  반복 7081 / 9295 | 시간 480[s] | 손실 2.28
# | 에폭 1 |  반복 7101 / 9295 | 시간 481[s] | 손실 2.30
# | 에폭 1 |  반복 7121 / 9295 | 시간 482[s] | 손실 2.26
# | 에폭 1 |  반복 7141 / 9295 | 시간 484[s] | 손실 2.24
# | 에폭 1 |  반복 7161 / 9295 | 시간 485[s] | 손실 2.27
# | 에폭 1 |  반복 7181 / 9295 | 시간 486[s] | 손실 2.31
# | 에폭 1 |  반복 7201 / 9295 | 시간 488[s] | 손실 2.30
# | 에폭 1 |  반복 7221 / 9295 | 시간 489[s] | 손실 2.25
# | 에폭 1 |  반복 7241 / 9295 | 시간 491[s] | 손실 2.28
# | 에폭 1 |  반복 7261 / 9295 | 시간 492[s] | 손실 2.29
# | 에폭 1 |  반복 7281 / 9295 | 시간 493[s] | 손실 2.29
# | 에폭 1 |  반복 7301 / 9295 | 시간 495[s] | 손실 2.30
# | 에폭 1 |  반복 7321 / 9295 | 시간 496[s] | 손실 2.31
# | 에폭 1 |  반복 7341 / 9295 | 시간 497[s] | 손실 2.25
# | 에폭 1 |  반복 7361 / 9295 | 시간 499[s] | 손실 2.27
# | 에폭 1 |  반복 7381 / 9295 | 시간 500[s] | 손실 2.26
# | 에폭 1 |  반복 7401 / 9295 | 시간 501[s] | 손실 2.21
# | 에폭 1 |  반복 7421 / 9295 | 시간 503[s] | 손실 2.25
# | 에폭 1 |  반복 7441 / 9295 | 시간 504[s] | 손실 2.23
# | 에폭 1 |  반복 7461 / 9295 | 시간 505[s] | 손실 2.25
# | 에폭 1 |  반복 7481 / 9295 | 시간 507[s] | 손실 2.27
# | 에폭 1 |  반복 7501 / 9295 | 시간 508[s] | 손실 2.23
# | 에폭 1 |  반복 7521 / 9295 | 시간 510[s] | 손실 2.26
# | 에폭 1 |  반복 7541 / 9295 | 시간 511[s] | 손실 2.26
# | 에폭 1 |  반복 7561 / 9295 | 시간 512[s] | 손실 2.28
# | 에폭 1 |  반복 7581 / 9295 | 시간 514[s] | 손실 2.25
# | 에폭 1 |  반복 7601 / 9295 | 시간 515[s] | 손실 2.28
# | 에폭 1 |  반복 7621 / 9295 | 시간 516[s] | 손실 2.28
# | 에폭 1 |  반복 7641 / 9295 | 시간 518[s] | 손실 2.31
# | 에폭 1 |  반복 7661 / 9295 | 시간 519[s] | 손실 2.28
# | 에폭 1 |  반복 7681 / 9295 | 시간 520[s] | 손실 2.26
# | 에폭 1 |  반복 7701 / 9295 | 시간 522[s] | 손실 2.30
# | 에폭 1 |  반복 7721 / 9295 | 시간 523[s] | 손실 2.28
# | 에폭 1 |  반복 7741 / 9295 | 시간 524[s] | 손실 2.28
# | 에폭 1 |  반복 7761 / 9295 | 시간 526[s] | 손실 2.25
# | 에폭 1 |  반복 7781 / 9295 | 시간 527[s] | 손실 2.27
# | 에폭 1 |  반복 7801 / 9295 | 시간 529[s] | 손실 2.26
# | 에폭 1 |  반복 7821 / 9295 | 시간 530[s] | 손실 2.26
# | 에폭 1 |  반복 7841 / 9295 | 시간 531[s] | 손실 2.27
# | 에폭 1 |  반복 7861 / 9295 | 시간 533[s] | 손실 2.27
# | 에폭 1 |  반복 7881 / 9295 | 시간 534[s] | 손실 2.28
# | 에폭 1 |  반복 7901 / 9295 | 시간 535[s] | 손실 2.24
# | 에폭 1 |  반복 7921 / 9295 | 시간 537[s] | 손실 2.24
# | 에폭 1 |  반복 7941 / 9295 | 시간 538[s] | 손실 2.28
# | 에폭 1 |  반복 7961 / 9295 | 시간 539[s] | 손실 2.24
# | 에폭 1 |  반복 7981 / 9295 | 시간 541[s] | 손실 2.24
# | 에폭 1 |  반복 8001 / 9295 | 시간 542[s] | 손실 2.26
# | 에폭 1 |  반복 8021 / 9295 | 시간 543[s] | 손실 2.24
# | 에폭 1 |  반복 8041 / 9295 | 시간 545[s] | 손실 2.25
# | 에폭 1 |  반복 8061 / 9295 | 시간 546[s] | 손실 2.26
# | 에폭 1 |  반복 8081 / 9295 | 시간 548[s] | 손실 2.24
# | 에폭 1 |  반복 8101 / 9295 | 시간 549[s] | 손실 2.25
# | 에폭 1 |  반복 8121 / 9295 | 시간 550[s] | 손실 2.23
# | 에폭 1 |  반복 8141 / 9295 | 시간 552[s] | 손실 2.26
# | 에폭 1 |  반복 8161 / 9295 | 시간 553[s] | 손실 2.24
# | 에폭 1 |  반복 8181 / 9295 | 시간 554[s] | 손실 2.20
# | 에폭 1 |  반복 8201 / 9295 | 시간 556[s] | 손실 2.23
# | 에폭 1 |  반복 8221 / 9295 | 시간 557[s] | 손실 2.25
# | 에폭 1 |  반복 8241 / 9295 | 시간 558[s] | 손실 2.25
# | 에폭 1 |  반복 8261 / 9295 | 시간 560[s] | 손실 2.26
# | 에폭 1 |  반복 8281 / 9295 | 시간 561[s] | 손실 2.24
# | 에폭 1 |  반복 8301 / 9295 | 시간 562[s] | 손실 2.25
# | 에폭 1 |  반복 8321 / 9295 | 시간 564[s] | 손실 2.25
# | 에폭 1 |  반복 8341 / 9295 | 시간 565[s] | 손실 2.26
# | 에폭 1 |  반복 8361 / 9295 | 시간 566[s] | 손실 2.23
# | 에폭 1 |  반복 8381 / 9295 | 시간 568[s] | 손실 2.24
# | 에폭 1 |  반복 8401 / 9295 | 시간 569[s] | 손실 2.23
# | 에폭 1 |  반복 8421 / 9295 | 시간 571[s] | 손실 2.26
# | 에폭 1 |  반복 8441 / 9295 | 시간 572[s] | 손실 2.24
# | 에폭 1 |  반복 8461 / 9295 | 시간 573[s] | 손실 2.22
# | 에폭 1 |  반복 8481 / 9295 | 시간 575[s] | 손실 2.20
# | 에폭 1 |  반복 8501 / 9295 | 시간 576[s] | 손실 2.29
# | 에폭 1 |  반복 8521 / 9295 | 시간 577[s] | 손실 2.25
# | 에폭 1 |  반복 8541 / 9295 | 시간 579[s] | 손실 2.22
# | 에폭 1 |  반복 8561 / 9295 | 시간 580[s] | 손실 2.22
# | 에폭 1 |  반복 8581 / 9295 | 시간 581[s] | 손실 2.25
# | 에폭 1 |  반복 8601 / 9295 | 시간 583[s] | 손실 2.22
# | 에폭 1 |  반복 8621 / 9295 | 시간 584[s] | 손실 2.25
# | 에폭 1 |  반복 8641 / 9295 | 시간 585[s] | 손실 2.26
# | 에폭 1 |  반복 8661 / 9295 | 시간 587[s] | 손실 2.25
# | 에폭 1 |  반복 8681 / 9295 | 시간 588[s] | 손실 2.20
# | 에폭 1 |  반복 8701 / 9295 | 시간 590[s] | 손실 2.24
# | 에폭 1 |  반복 8721 / 9295 | 시간 591[s] | 손실 2.23
# | 에폭 1 |  반복 8741 / 9295 | 시간 592[s] | 손실 2.22
# | 에폭 1 |  반복 8761 / 9295 | 시간 594[s] | 손실 2.26
# | 에폭 1 |  반복 8781 / 9295 | 시간 595[s] | 손실 2.27
# | 에폭 1 |  반복 8801 / 9295 | 시간 596[s] | 손실 2.22
# | 에폭 1 |  반복 8821 / 9295 | 시간 598[s] | 손실 2.22
# | 에폭 1 |  반복 8841 / 9295 | 시간 599[s] | 손실 2.23
# | 에폭 1 |  반복 8861 / 9295 | 시간 600[s] | 손실 2.23
# | 에폭 1 |  반복 8881 / 9295 | 시간 602[s] | 손실 2.24
# | 에폭 1 |  반복 8901 / 9295 | 시간 603[s] | 손실 2.19
# | 에폭 1 |  반복 8921 / 9295 | 시간 604[s] | 손실 2.20
# | 에폭 1 |  반복 8941 / 9295 | 시간 606[s] | 손실 2.21
# | 에폭 1 |  반복 8961 / 9295 | 시간 607[s] | 손실 2.22
# | 에폭 1 |  반복 8981 / 9295 | 시간 609[s] | 손실 2.24
# | 에폭 1 |  반복 9001 / 9295 | 시간 610[s] | 손실 2.23
# | 에폭 1 |  반복 9021 / 9295 | 시간 611[s] | 손실 2.25
# | 에폭 1 |  반복 9041 / 9295 | 시간 613[s] | 손실 2.20
# | 에폭 1 |  반복 9061 / 9295 | 시간 614[s] | 손실 2.21
# | 에폭 1 |  반복 9081 / 9295 | 시간 615[s] | 손실 2.24
# | 에폭 1 |  반복 9101 / 9295 | 시간 617[s] | 손실 2.21
# | 에폭 1 |  반복 9121 / 9295 | 시간 618[s] | 손실 2.22
# | 에폭 1 |  반복 9141 / 9295 | 시간 619[s] | 손실 2.21
# | 에폭 1 |  반복 9161 / 9295 | 시간 621[s] | 손실 2.19
# | 에폭 1 |  반복 9181 / 9295 | 시간 622[s] | 손실 2.20
# | 에폭 1 |  반복 9201 / 9295 | 시간 623[s] | 손실 2.20
# | 에폭 1 |  반복 9221 / 9295 | 시간 625[s] | 손실 2.22
# | 에폭 1 |  반복 9241 / 9295 | 시간 626[s] | 손실 2.24
# | 에폭 1 |  반복 9261 / 9295 | 시간 628[s] | 손실 2.20
# | 에폭 1 |  반복 9281 / 9295 | 시간 629[s] | 손실 2.21
# | 에폭 2 |  반복 1 / 9295 | 시간 630[s] | 손실 2.22
# | 에폭 2 |  반복 21 / 9295 | 시간 631[s] | 손실 2.18
# | 에폭 2 |  반복 41 / 9295 | 시간 633[s] | 손실 2.17
# | 에폭 2 |  반복 61 / 9295 | 시간 634[s] | 손실 2.17
# | 에폭 2 |  반복 81 / 9295 | 시간 635[s] | 손실 2.16
# | 에폭 2 |  반복 101 / 9295 | 시간 637[s] | 손실 2.20
# | 에폭 2 |  반복 121 / 9295 | 시간 638[s] | 손실 2.19
# | 에폭 2 |  반복 141 / 9295 | 시간 640[s] | 손실 2.18
# | 에폭 2 |  반복 161 / 9295 | 시간 641[s] | 손실 2.19
# | 에폭 2 |  반복 181 / 9295 | 시간 642[s] | 손실 2.16
# | 에폭 2 |  반복 201 / 9295 | 시간 644[s] | 손실 2.19
# | 에폭 2 |  반복 221 / 9295 | 시간 645[s] | 손실 2.17
# | 에폭 2 |  반복 241 / 9295 | 시간 646[s] | 손실 2.15
# | 에폭 2 |  반복 261 / 9295 | 시간 648[s] | 손실 2.21
# | 에폭 2 |  반복 281 / 9295 | 시간 649[s] | 손실 2.14
# | 에폭 2 |  반복 301 / 9295 | 시간 650[s] | 손실 2.15
# | 에폭 2 |  반복 321 / 9295 | 시간 652[s] | 손실 2.19
# | 에폭 2 |  반복 341 / 9295 | 시간 653[s] | 손실 2.18
# | 에폭 2 |  반복 361 / 9295 | 시간 654[s] | 손실 2.18
# | 에폭 2 |  반복 381 / 9295 | 시간 656[s] | 손실 2.19
# | 에폭 2 |  반복 401 / 9295 | 시간 657[s] | 손실 2.21
# | 에폭 2 |  반복 421 / 9295 | 시간 658[s] | 손실 2.16
# | 에폭 2 |  반복 441 / 9295 | 시간 660[s] | 손실 2.11
# | 에폭 2 |  반복 461 / 9295 | 시간 661[s] | 손실 2.20
# | 에폭 2 |  반복 481 / 9295 | 시간 663[s] | 손실 2.15
# | 에폭 2 |  반복 501 / 9295 | 시간 664[s] | 손실 2.21
# | 에폭 2 |  반복 521 / 9295 | 시간 665[s] | 손실 2.18
# | 에폭 2 |  반복 541 / 9295 | 시간 667[s] | 손실 2.17
# | 에폭 2 |  반복 561 / 9295 | 시간 668[s] | 손실 2.18
# | 에폭 2 |  반복 581 / 9295 | 시간 669[s] | 손실 2.17
# | 에폭 2 |  반복 601 / 9295 | 시간 671[s] | 손실 2.17
# | 에폭 2 |  반복 621 / 9295 | 시간 672[s] | 손실 2.16
# | 에폭 2 |  반복 641 / 9295 | 시간 673[s] | 손실 2.20
# | 에폭 2 |  반복 661 / 9295 | 시간 675[s] | 손실 2.19
# | 에폭 2 |  반복 681 / 9295 | 시간 676[s] | 손실 2.16
# | 에폭 2 |  반복 701 / 9295 | 시간 678[s] | 손실 2.20
# | 에폭 2 |  반복 721 / 9295 | 시간 679[s] | 손실 2.18
# | 에폭 2 |  반복 741 / 9295 | 시간 680[s] | 손실 2.15
# | 에폭 2 |  반복 761 / 9295 | 시간 682[s] | 손실 2.20
# | 에폭 2 |  반복 781 / 9295 | 시간 683[s] | 손실 2.14
# | 에폭 2 |  반복 801 / 9295 | 시간 684[s] | 손실 2.18
# | 에폭 2 |  반복 821 / 9295 | 시간 686[s] | 손실 2.20
# | 에폭 2 |  반복 841 / 9295 | 시간 687[s] | 손실 2.16
# | 에폭 2 |  반복 861 / 9295 | 시간 688[s] | 손실 2.18
# | 에폭 2 |  반복 881 / 9295 | 시간 690[s] | 손실 2.16
# | 에폭 2 |  반복 901 / 9295 | 시간 691[s] | 손실 2.17
# | 에폭 2 |  반복 921 / 9295 | 시간 692[s] | 손실 2.14
# | 에폭 2 |  반복 941 / 9295 | 시간 694[s] | 손실 2.13
# | 에폭 2 |  반복 961 / 9295 | 시간 695[s] | 손실 2.16
# | 에폭 2 |  반복 981 / 9295 | 시간 696[s] | 손실 2.15
# | 에폭 2 |  반복 1001 / 9295 | 시간 698[s] | 손실 2.18
# | 에폭 2 |  반복 1021 / 9295 | 시간 699[s] | 손실 2.16
# | 에폭 2 |  반복 1041 / 9295 | 시간 701[s] | 손실 2.18
# | 에폭 2 |  반복 1061 / 9295 | 시간 702[s] | 손실 2.18
# | 에폭 2 |  반복 1081 / 9295 | 시간 703[s] | 손실 2.13
# | 에폭 2 |  반복 1101 / 9295 | 시간 705[s] | 손실 2.15
# | 에폭 2 |  반복 1121 / 9295 | 시간 706[s] | 손실 2.16
# | 에폭 2 |  반복 1141 / 9295 | 시간 707[s] | 손실 2.14
# | 에폭 2 |  반복 1161 / 9295 | 시간 709[s] | 손실 2.17
# | 에폭 2 |  반복 1181 / 9295 | 시간 710[s] | 손실 2.17
# | 에폭 2 |  반복 1201 / 9295 | 시간 711[s] | 손실 2.19
# | 에폭 2 |  반복 1221 / 9295 | 시간 713[s] | 손실 2.15
# | 에폭 2 |  반복 1241 / 9295 | 시간 714[s] | 손실 2.12
# | 에폭 2 |  반복 1261 / 9295 | 시간 716[s] | 손실 2.14
# | 에폭 2 |  반복 1281 / 9295 | 시간 717[s] | 손실 2.14
# | 에폭 2 |  반복 1301 / 9295 | 시간 718[s] | 손실 2.15
# | 에폭 2 |  반복 1321 / 9295 | 시간 720[s] | 손실 2.13
# | 에폭 2 |  반복 1341 / 9295 | 시간 721[s] | 손실 2.13
# | 에폭 2 |  반복 1361 / 9295 | 시간 722[s] | 손실 2.13
# | 에폭 2 |  반복 1381 / 9295 | 시간 724[s] | 손실 2.11
# | 에폭 2 |  반복 1401 / 9295 | 시간 725[s] | 손실 2.16
# | 에폭 2 |  반복 1421 / 9295 | 시간 726[s] | 손실 2.16
# | 에폭 2 |  반복 1441 / 9295 | 시간 728[s] | 손실 2.15
# | 에폭 2 |  반복 1461 / 9295 | 시간 729[s] | 손실 2.12
# | 에폭 2 |  반복 1481 / 9295 | 시간 730[s] | 손실 2.14
# | 에폭 2 |  반복 1501 / 9295 | 시간 732[s] | 손실 2.16
# | 에폭 2 |  반복 1521 / 9295 | 시간 733[s] | 손실 2.17
# | 에폭 2 |  반복 1541 / 9295 | 시간 734[s] | 손실 2.15
# | 에폭 2 |  반복 1561 / 9295 | 시간 736[s] | 손실 2.14
# | 에폭 2 |  반복 1581 / 9295 | 시간 737[s] | 손실 2.17
# | 에폭 2 |  반복 1601 / 9295 | 시간 739[s] | 손실 2.11
# | 에폭 2 |  반복 1621 / 9295 | 시간 740[s] | 손실 2.15
# | 에폭 2 |  반복 1641 / 9295 | 시간 741[s] | 손실 2.12
# | 에폭 2 |  반복 1661 / 9295 | 시간 743[s] | 손실 2.14
# | 에폭 2 |  반복 1681 / 9295 | 시간 744[s] | 손실 2.13
# | 에폭 2 |  반복 1701 / 9295 | 시간 745[s] | 손실 2.11
# | 에폭 2 |  반복 1721 / 9295 | 시간 747[s] | 손실 2.14
# | 에폭 2 |  반복 1741 / 9295 | 시간 748[s] | 손실 2.12
# | 에폭 2 |  반복 1761 / 9295 | 시간 749[s] | 손실 2.15
# | 에폭 2 |  반복 1781 / 9295 | 시간 751[s] | 손실 2.09
# | 에폭 2 |  반복 1801 / 9295 | 시간 752[s] | 손실 2.16
# | 에폭 2 |  반복 1821 / 9295 | 시간 753[s] | 손실 2.12
# | 에폭 2 |  반복 1841 / 9295 | 시간 755[s] | 손실 2.13
# | 에폭 2 |  반복 1861 / 9295 | 시간 756[s] | 손실 2.15
# | 에폭 2 |  반복 1881 / 9295 | 시간 758[s] | 손실 2.15
# | 에폭 2 |  반복 1901 / 9295 | 시간 759[s] | 손실 2.17
# | 에폭 2 |  반복 1921 / 9295 | 시간 760[s] | 손실 2.18
# | 에폭 2 |  반복 1941 / 9295 | 시간 762[s] | 손실 2.11
# | 에폭 2 |  반복 1961 / 9295 | 시간 763[s] | 손실 2.14
# | 에폭 2 |  반복 1981 / 9295 | 시간 764[s] | 손실 2.10
# | 에폭 2 |  반복 2001 / 9295 | 시간 766[s] | 손실 2.13
# | 에폭 2 |  반복 2021 / 9295 | 시간 767[s] | 손실 2.15
# | 에폭 2 |  반복 2041 / 9295 | 시간 768[s] | 손실 2.11
# | 에폭 2 |  반복 2061 / 9295 | 시간 770[s] | 손실 2.14
# | 에폭 2 |  반복 2081 / 9295 | 시간 771[s] | 손실 2.13
# | 에폭 2 |  반복 2101 / 9295 | 시간 773[s] | 손실 2.15
# | 에폭 2 |  반복 2121 / 9295 | 시간 774[s] | 손실 2.13
# | 에폭 2 |  반복 2141 / 9295 | 시간 775[s] | 손실 2.12
# | 에폭 2 |  반복 2161 / 9295 | 시간 777[s] | 손실 2.14
# | 에폭 2 |  반복 2181 / 9295 | 시간 778[s] | 손실 2.12
# | 에폭 2 |  반복 2201 / 9295 | 시간 779[s] | 손실 2.13
# | 에폭 2 |  반복 2221 / 9295 | 시간 781[s] | 손실 2.11
# | 에폭 2 |  반복 2241 / 9295 | 시간 782[s] | 손실 2.13
# | 에폭 2 |  반복 2261 / 9295 | 시간 783[s] | 손실 2.13
# | 에폭 2 |  반복 2281 / 9295 | 시간 785[s] | 손실 2.14
# | 에폭 2 |  반복 2301 / 9295 | 시간 786[s] | 손실 2.13
# | 에폭 2 |  반복 2321 / 9295 | 시간 787[s] | 손실 2.13
# | 에폭 2 |  반복 2341 / 9295 | 시간 789[s] | 손실 2.14
# | 에폭 2 |  반복 2361 / 9295 | 시간 790[s] | 손실 2.15
# | 에폭 2 |  반복 2381 / 9295 | 시간 792[s] | 손실 2.13
# | 에폭 2 |  반복 2401 / 9295 | 시간 793[s] | 손실 2.09
# | 에폭 2 |  반복 2421 / 9295 | 시간 794[s] | 손실 2.12
# | 에폭 2 |  반복 2441 / 9295 | 시간 796[s] | 손실 2.11
# | 에폭 2 |  반복 2461 / 9295 | 시간 797[s] | 손실 2.15
# | 에폭 2 |  반복 2481 / 9295 | 시간 798[s] | 손실 2.11
# | 에폭 2 |  반복 2501 / 9295 | 시간 800[s] | 손실 2.11
# | 에폭 2 |  반복 2521 / 9295 | 시간 801[s] | 손실 2.13
# | 에폭 2 |  반복 2541 / 9295 | 시간 802[s] | 손실 2.12
# | 에폭 2 |  반복 2561 / 9295 | 시간 804[s] | 손실 2.14
# | 에폭 2 |  반복 2581 / 9295 | 시간 805[s] | 손실 2.15
# | 에폭 2 |  반복 2601 / 9295 | 시간 806[s] | 손실 2.11
# | 에폭 2 |  반복 2621 / 9295 | 시간 808[s] | 손실 2.11
# | 에폭 2 |  반복 2641 / 9295 | 시간 809[s] | 손실 2.12
# | 에폭 2 |  반복 2661 / 9295 | 시간 811[s] | 손실 2.14
# | 에폭 2 |  반복 2681 / 9295 | 시간 812[s] | 손실 2.09
# | 에폭 2 |  반복 2701 / 9295 | 시간 813[s] | 손실 2.10
# | 에폭 2 |  반복 2721 / 9295 | 시간 815[s] | 손실 2.12
# | 에폭 2 |  반복 2741 / 9295 | 시간 816[s] | 손실 2.13
# | 에폭 2 |  반복 2761 / 9295 | 시간 817[s] | 손실 2.12
# | 에폭 2 |  반복 2781 / 9295 | 시간 819[s] | 손실 2.09
# | 에폭 2 |  반복 2801 / 9295 | 시간 820[s] | 손실 2.13
# | 에폭 2 |  반복 2821 / 9295 | 시간 821[s] | 손실 2.10
# | 에폭 2 |  반복 2841 / 9295 | 시간 823[s] | 손실 2.08
# | 에폭 2 |  반복 2861 / 9295 | 시간 824[s] | 손실 2.10
# | 에폭 2 |  반복 2881 / 9295 | 시간 825[s] | 손실 2.11
# | 에폭 2 |  반복 2901 / 9295 | 시간 827[s] | 손실 2.09
# | 에폭 2 |  반복 2921 / 9295 | 시간 828[s] | 손실 2.11
# | 에폭 2 |  반복 2941 / 9295 | 시간 830[s] | 손실 2.14
# | 에폭 2 |  반복 2961 / 9295 | 시간 831[s] | 손실 2.07
# | 에폭 2 |  반복 2981 / 9295 | 시간 832[s] | 손실 2.12
# | 에폭 2 |  반복 3001 / 9295 | 시간 834[s] | 손실 2.13
# | 에폭 2 |  반복 3021 / 9295 | 시간 835[s] | 손실 2.07
# | 에폭 2 |  반복 3041 / 9295 | 시간 836[s] | 손실 2.13
# | 에폭 2 |  반복 3061 / 9295 | 시간 838[s] | 손실 2.14
# | 에폭 2 |  반복 3081 / 9295 | 시간 839[s] | 손실 2.13
# | 에폭 2 |  반복 3101 / 9295 | 시간 840[s] | 손실 2.11
# | 에폭 2 |  반복 3121 / 9295 | 시간 842[s] | 손실 2.11
# | 에폭 2 |  반복 3141 / 9295 | 시간 843[s] | 손실 2.10
# | 에폭 2 |  반복 3161 / 9295 | 시간 844[s] | 손실 2.10
# | 에폭 2 |  반복 3181 / 9295 | 시간 846[s] | 손실 2.08
# | 에폭 2 |  반복 3201 / 9295 | 시간 847[s] | 손실 2.11
# | 에폭 2 |  반복 3221 / 9295 | 시간 849[s] | 손실 2.12
# | 에폭 2 |  반복 3241 / 9295 | 시간 850[s] | 손실 2.10
# | 에폭 2 |  반복 3261 / 9295 | 시간 851[s] | 손실 2.10
# | 에폭 2 |  반복 3281 / 9295 | 시간 853[s] | 손실 2.11
# | 에폭 2 |  반복 3301 / 9295 | 시간 854[s] | 손실 2.08
# | 에폭 2 |  반복 3321 / 9295 | 시간 855[s] | 손실 2.12
# | 에폭 2 |  반복 3341 / 9295 | 시간 857[s] | 손실 2.09
# | 에폭 2 |  반복 3361 / 9295 | 시간 858[s] | 손실 2.10
# | 에폭 2 |  반복 3381 / 9295 | 시간 859[s] | 손실 2.13
# | 에폭 2 |  반복 3401 / 9295 | 시간 861[s] | 손실 2.10
# | 에폭 2 |  반복 3421 / 9295 | 시간 862[s] | 손실 2.11
# | 에폭 2 |  반복 3441 / 9295 | 시간 863[s] | 손실 2.12
# | 에폭 2 |  반복 3461 / 9295 | 시간 865[s] | 손실 2.10
# | 에폭 2 |  반복 3481 / 9295 | 시간 866[s] | 손실 2.12
# | 에폭 2 |  반복 3501 / 9295 | 시간 868[s] | 손실 2.07
# | 에폭 2 |  반복 3521 / 9295 | 시간 869[s] | 손실 2.11
# | 에폭 2 |  반복 3541 / 9295 | 시간 870[s] | 손실 2.13
# | 에폭 2 |  반복 3561 / 9295 | 시간 872[s] | 손실 2.08
# | 에폭 2 |  반복 3581 / 9295 | 시간 873[s] | 손실 2.10
# | 에폭 2 |  반복 3601 / 9295 | 시간 874[s] | 손실 2.07
# | 에폭 2 |  반복 3621 / 9295 | 시간 876[s] | 손실 2.12
# | 에폭 2 |  반복 3641 / 9295 | 시간 877[s] | 손실 2.10
# | 에폭 2 |  반복 3661 / 9295 | 시간 878[s] | 손실 2.06
# | 에폭 2 |  반복 3681 / 9295 | 시간 880[s] | 손실 2.10
# | 에폭 2 |  반복 3701 / 9295 | 시간 881[s] | 손실 2.10
# | 에폭 2 |  반복 3721 / 9295 | 시간 882[s] | 손실 2.08
# | 에폭 2 |  반복 3741 / 9295 | 시간 884[s] | 손실 2.10
# | 에폭 2 |  반복 3761 / 9295 | 시간 885[s] | 손실 2.10
# | 에폭 2 |  반복 3781 / 9295 | 시간 887[s] | 손실 2.10
# | 에폭 2 |  반복 3801 / 9295 | 시간 888[s] | 손실 2.11
# | 에폭 2 |  반복 3821 / 9295 | 시간 889[s] | 손실 2.13
# | 에폭 2 |  반복 3841 / 9295 | 시간 891[s] | 손실 2.11
# | 에폭 2 |  반복 3861 / 9295 | 시간 892[s] | 손실 2.05
# | 에폭 2 |  반복 3881 / 9295 | 시간 893[s] | 손실 2.13
# | 에폭 2 |  반복 3901 / 9295 | 시간 895[s] | 손실 2.11
# | 에폭 2 |  반복 3921 / 9295 | 시간 896[s] | 손실 2.07
# | 에폭 2 |  반복 3941 / 9295 | 시간 897[s] | 손실 2.10
# | 에폭 2 |  반복 3961 / 9295 | 시간 899[s] | 손실 2.12
# | 에폭 2 |  반복 3981 / 9295 | 시간 900[s] | 손실 2.08
# | 에폭 2 |  반복 4001 / 9295 | 시간 901[s] | 손실 2.09
# | 에폭 2 |  반복 4021 / 9295 | 시간 903[s] | 손실 2.05
# | 에폭 2 |  반복 4041 / 9295 | 시간 904[s] | 손실 2.10
# | 에폭 2 |  반복 4061 / 9295 | 시간 906[s] | 손실 2.11
# | 에폭 2 |  반복 4081 / 9295 | 시간 907[s] | 손실 2.13
# | 에폭 2 |  반복 4101 / 9295 | 시간 908[s] | 손실 2.06
# | 에폭 2 |  반복 4121 / 9295 | 시간 910[s] | 손실 2.08
# | 에폭 2 |  반복 4141 / 9295 | 시간 911[s] | 손실 2.07
# | 에폭 2 |  반복 4161 / 9295 | 시간 912[s] | 손실 2.09
# | 에폭 2 |  반복 4181 / 9295 | 시간 914[s] | 손실 2.15
# | 에폭 2 |  반복 4201 / 9295 | 시간 915[s] | 손실 2.08
# | 에폭 2 |  반복 4221 / 9295 | 시간 916[s] | 손실 2.08
# | 에폭 2 |  반복 4241 / 9295 | 시간 918[s] | 손실 2.12
# | 에폭 2 |  반복 4261 / 9295 | 시간 919[s] | 손실 2.11
# | 에폭 2 |  반복 4281 / 9295 | 시간 920[s] | 손실 2.11
# | 에폭 2 |  반복 4301 / 9295 | 시간 922[s] | 손실 2.08
# | 에폭 2 |  반복 4321 / 9295 | 시간 923[s] | 손실 2.11
# | 에폭 2 |  반복 4341 / 9295 | 시간 925[s] | 손실 2.12
# | 에폭 2 |  반복 4361 / 9295 | 시간 926[s] | 손실 2.10
# | 에폭 2 |  반복 4381 / 9295 | 시간 927[s] | 손실 2.13
# | 에폭 2 |  반복 4401 / 9295 | 시간 929[s] | 손실 2.09
# | 에폭 2 |  반복 4421 / 9295 | 시간 930[s] | 손실 2.11
# | 에폭 2 |  반복 4441 / 9295 | 시간 931[s] | 손실 2.07
# | 에폭 2 |  반복 4461 / 9295 | 시간 933[s] | 손실 2.09
# | 에폭 2 |  반복 4481 / 9295 | 시간 934[s] | 손실 2.10
# | 에폭 2 |  반복 4501 / 9295 | 시간 935[s] | 손실 2.07
# | 에폭 2 |  반복 4521 / 9295 | 시간 937[s] | 손실 2.08
# | 에폭 2 |  반복 4541 / 9295 | 시간 938[s] | 손실 2.07
# | 에폭 2 |  반복 4561 / 9295 | 시간 940[s] | 손실 2.09
# | 에폭 2 |  반복 4581 / 9295 | 시간 941[s] | 손실 2.10
# | 에폭 2 |  반복 4601 / 9295 | 시간 942[s] | 손실 2.11
# | 에폭 2 |  반복 4621 / 9295 | 시간 944[s] | 손실 2.06
# | 에폭 2 |  반복 4641 / 9295 | 시간 945[s] | 손실 2.11
# | 에폭 2 |  반복 4661 / 9295 | 시간 946[s] | 손실 2.08
# | 에폭 2 |  반복 4681 / 9295 | 시간 948[s] | 손실 2.07
# | 에폭 2 |  반복 4701 / 9295 | 시간 949[s] | 손실 2.07
# | 에폭 2 |  반복 4721 / 9295 | 시간 950[s] | 손실 2.09
# | 에폭 2 |  반복 4741 / 9295 | 시간 952[s] | 손실 2.10
# | 에폭 2 |  반복 4761 / 9295 | 시간 953[s] | 손실 2.08
# | 에폭 2 |  반복 4781 / 9295 | 시간 955[s] | 손실 2.06
# | 에폭 2 |  반복 4801 / 9295 | 시간 956[s] | 손실 2.05
# | 에폭 2 |  반복 4821 / 9295 | 시간 957[s] | 손실 2.09
# | 에폭 2 |  반복 4841 / 9295 | 시간 959[s] | 손실 2.06
# | 에폭 2 |  반복 4861 / 9295 | 시간 960[s] | 손실 2.05
# | 에폭 2 |  반복 4881 / 9295 | 시간 961[s] | 손실 2.09
# | 에폭 2 |  반복 4901 / 9295 | 시간 963[s] | 손실 2.08
# | 에폭 2 |  반복 4921 / 9295 | 시간 964[s] | 손실 2.08
# | 에폭 2 |  반복 4941 / 9295 | 시간 965[s] | 손실 2.07
# | 에폭 2 |  반복 4961 / 9295 | 시간 967[s] | 손실 2.05
# | 에폭 2 |  반복 4981 / 9295 | 시간 968[s] | 손실 2.07
# | 에폭 2 |  반복 5001 / 9295 | 시간 970[s] | 손실 2.05
# | 에폭 2 |  반복 5021 / 9295 | 시간 971[s] | 손실 2.12
# | 에폭 2 |  반복 5041 / 9295 | 시간 972[s] | 손실 2.05
# | 에폭 2 |  반복 5061 / 9295 | 시간 974[s] | 손실 2.13
# | 에폭 2 |  반복 5081 / 9295 | 시간 975[s] | 손실 2.05
# | 에폭 2 |  반복 5101 / 9295 | 시간 976[s] | 손실 2.05
# | 에폭 2 |  반복 5121 / 9295 | 시간 978[s] | 손실 2.06
# | 에폭 2 |  반복 5141 / 9295 | 시간 979[s] | 손실 2.07
# | 에폭 2 |  반복 5161 / 9295 | 시간 980[s] | 손실 2.10
# | 에폭 2 |  반복 5181 / 9295 | 시간 982[s] | 손실 2.10
# | 에폭 2 |  반복 5201 / 9295 | 시간 983[s] | 손실 2.08
# | 에폭 2 |  반복 5221 / 9295 | 시간 985[s] | 손실 2.09
# | 에폭 2 |  반복 5241 / 9295 | 시간 986[s] | 손실 2.08
# | 에폭 2 |  반복 5261 / 9295 | 시간 987[s] | 손실 2.08
# | 에폭 2 |  반복 5281 / 9295 | 시간 989[s] | 손실 2.10
# | 에폭 2 |  반복 5301 / 9295 | 시간 990[s] | 손실 2.09
# | 에폭 2 |  반복 5321 / 9295 | 시간 991[s] | 손실 2.09
# | 에폭 2 |  반복 5341 / 9295 | 시간 993[s] | 손실 2.02
# | 에폭 2 |  반복 5361 / 9295 | 시간 994[s] | 손실 2.05
# | 에폭 2 |  반복 5381 / 9295 | 시간 995[s] | 손실 2.06
# | 에폭 2 |  반복 5401 / 9295 | 시간 997[s] | 손실 2.08
# | 에폭 2 |  반복 5421 / 9295 | 시간 998[s] | 손실 2.04
# | 에폭 2 |  반복 5441 / 9295 | 시간 1000[s] | 손실 2.08
# | 에폭 2 |  반복 5461 / 9295 | 시간 1001[s] | 손실 2.08
# | 에폭 2 |  반복 5481 / 9295 | 시간 1002[s] | 손실 2.05
# | 에폭 2 |  반복 5501 / 9295 | 시간 1004[s] | 손실 2.05
# | 에폭 2 |  반복 5521 / 9295 | 시간 1005[s] | 손실 2.06
# | 에폭 2 |  반복 5541 / 9295 | 시간 1006[s] | 손실 2.09
# | 에폭 2 |  반복 5561 / 9295 | 시간 1008[s] | 손실 2.07
# | 에폭 2 |  반복 5581 / 9295 | 시간 1009[s] | 손실 2.03
# | 에폭 2 |  반복 5601 / 9295 | 시간 1010[s] | 손실 2.07
# | 에폭 2 |  반복 5621 / 9295 | 시간 1012[s] | 손실 2.09
# | 에폭 2 |  반복 5641 / 9295 | 시간 1013[s] | 손실 2.07
# | 에폭 2 |  반복 5661 / 9295 | 시간 1015[s] | 손실 2.05
# | 에폭 2 |  반복 5681 / 9295 | 시간 1016[s] | 손실 2.09
# | 에폭 2 |  반복 5701 / 9295 | 시간 1017[s] | 손실 2.06
# | 에폭 2 |  반복 5721 / 9295 | 시간 1019[s] | 손실 2.03
# | 에폭 2 |  반복 5741 / 9295 | 시간 1020[s] | 손실 2.05
# | 에폭 2 |  반복 5761 / 9295 | 시간 1021[s] | 손실 2.06
# | 에폭 2 |  반복 5781 / 9295 | 시간 1023[s] | 손실 2.06
# | 에폭 2 |  반복 5801 / 9295 | 시간 1024[s] | 손실 2.07
# | 에폭 2 |  반복 5821 / 9295 | 시간 1025[s] | 손실 2.09
# | 에폭 2 |  반복 5841 / 9295 | 시간 1027[s] | 손실 2.07
# | 에폭 2 |  반복 5861 / 9295 | 시간 1028[s] | 손실 2.05
# | 에폭 2 |  반복 5881 / 9295 | 시간 1030[s] | 손실 2.08
# | 에폭 2 |  반복 5901 / 9295 | 시간 1031[s] | 손실 2.05
# | 에폭 2 |  반복 5921 / 9295 | 시간 1032[s] | 손실 2.06
# | 에폭 2 |  반복 5941 / 9295 | 시간 1034[s] | 손실 2.08
# | 에폭 2 |  반복 5961 / 9295 | 시간 1035[s] | 손실 2.12
# | 에폭 2 |  반복 5981 / 9295 | 시간 1036[s] | 손실 2.06
# | 에폭 2 |  반복 6001 / 9295 | 시간 1038[s] | 손실 2.04
# | 에폭 2 |  반복 6021 / 9295 | 시간 1039[s] | 손실 2.05
# | 에폭 2 |  반복 6041 / 9295 | 시간 1040[s] | 손실 2.04
# | 에폭 2 |  반복 6061 / 9295 | 시간 1042[s] | 손실 2.08
# | 에폭 2 |  반복 6081 / 9295 | 시간 1043[s] | 손실 2.05
# | 에폭 2 |  반복 6101 / 9295 | 시간 1045[s] | 손실 2.08
# | 에폭 2 |  반복 6121 / 9295 | 시간 1046[s] | 손실 2.09
# | 에폭 2 |  반복 6141 / 9295 | 시간 1047[s] | 손실 2.07
# | 에폭 2 |  반복 6161 / 9295 | 시간 1049[s] | 손실 2.07
# | 에폭 2 |  반복 6181 / 9295 | 시간 1050[s] | 손실 2.04
# | 에폭 2 |  반복 6201 / 9295 | 시간 1051[s] | 손실 2.08
# | 에폭 2 |  반복 6221 / 9295 | 시간 1053[s] | 손실 2.04
# | 에폭 2 |  반복 6241 / 9295 | 시간 1054[s] | 손실 2.03
# | 에폭 2 |  반복 6261 / 9295 | 시간 1055[s] | 손실 2.06
# | 에폭 2 |  반복 6281 / 9295 | 시간 1057[s] | 손실 2.06
# | 에폭 2 |  반복 6301 / 9295 | 시간 1058[s] | 손실 2.04
# | 에폭 2 |  반복 6321 / 9295 | 시간 1060[s] | 손실 2.07
# | 에폭 2 |  반복 6341 / 9295 | 시간 1061[s] | 손실 2.06
# | 에폭 2 |  반복 6361 / 9295 | 시간 1062[s] | 손실 2.09
# | 에폭 2 |  반복 6381 / 9295 | 시간 1064[s] | 손실 2.07
# | 에폭 2 |  반복 6401 / 9295 | 시간 1065[s] | 손실 2.06
# | 에폭 2 |  반복 6421 / 9295 | 시간 1066[s] | 손실 2.04
# | 에폭 2 |  반복 6441 / 9295 | 시간 1068[s] | 손실 2.06
# | 에폭 2 |  반복 6461 / 9295 | 시간 1069[s] | 손실 2.04
# | 에폭 2 |  반복 6481 / 9295 | 시간 1070[s] | 손실 2.04
# | 에폭 2 |  반복 6501 / 9295 | 시간 1072[s] | 손실 2.04
# | 에폭 2 |  반복 6521 / 9295 | 시간 1073[s] | 손실 2.05
# | 에폭 2 |  반복 6541 / 9295 | 시간 1075[s] | 손실 2.10
# | 에폭 2 |  반복 6561 / 9295 | 시간 1076[s] | 손실 2.08
# | 에폭 2 |  반복 6581 / 9295 | 시간 1077[s] | 손실 2.05
# | 에폭 2 |  반복 6601 / 9295 | 시간 1079[s] | 손실 2.04
# | 에폭 2 |  반복 6621 / 9295 | 시간 1080[s] | 손실 2.04
# | 에폭 2 |  반복 6641 / 9295 | 시간 1081[s] | 손실 2.04
# | 에폭 2 |  반복 6661 / 9295 | 시간 1083[s] | 손실 2.05
# | 에폭 2 |  반복 6681 / 9295 | 시간 1084[s] | 손실 2.05
# | 에폭 2 |  반복 6701 / 9295 | 시간 1085[s] | 손실 2.02
# | 에폭 2 |  반복 6721 / 9295 | 시간 1087[s] | 손실 2.09
# | 에폭 2 |  반복 6741 / 9295 | 시간 1088[s] | 손실 2.06
# | 에폭 2 |  반복 6761 / 9295 | 시간 1089[s] | 손실 2.05
# | 에폭 2 |  반복 6781 / 9295 | 시간 1091[s] | 손실 2.04
# | 에폭 2 |  반복 6801 / 9295 | 시간 1092[s] | 손실 2.04
# | 에폭 2 |  반복 6821 / 9295 | 시간 1094[s] | 손실 2.02
# | 에폭 2 |  반복 6841 / 9295 | 시간 1095[s] | 손실 2.04
# | 에폭 2 |  반복 6861 / 9295 | 시간 1096[s] | 손실 2.06
# | 에폭 2 |  반복 6881 / 9295 | 시간 1098[s] | 손실 2.06
# | 에폭 2 |  반복 6901 / 9295 | 시간 1099[s] | 손실 2.05
# | 에폭 2 |  반복 6921 / 9295 | 시간 1100[s] | 손실 2.07
# | 에폭 2 |  반복 6941 / 9295 | 시간 1102[s] | 손실 2.02
# | 에폭 2 |  반복 6961 / 9295 | 시간 1103[s] | 손실 2.02
# | 에폭 2 |  반복 6981 / 9295 | 시간 1104[s] | 손실 2.09
# | 에폭 2 |  반복 7001 / 9295 | 시간 1106[s] | 손실 2.04
# | 에폭 2 |  반복 7021 / 9295 | 시간 1107[s] | 손실 2.05
# | 에폭 2 |  반복 7041 / 9295 | 시간 1109[s] | 손실 2.02
# | 에폭 2 |  반복 7061 / 9295 | 시간 1110[s] | 손실 2.04
# | 에폭 2 |  반복 7081 / 9295 | 시간 1111[s] | 손실 2.04
# | 에폭 2 |  반복 7101 / 9295 | 시간 1113[s] | 손실 2.06
# | 에폭 2 |  반복 7121 / 9295 | 시간 1114[s] | 손실 2.04
# | 에폭 2 |  반복 7141 / 9295 | 시간 1115[s] | 손실 2.03
# | 에폭 2 |  반복 7161 / 9295 | 시간 1117[s] | 손실 2.04
# | 에폭 2 |  반복 7181 / 9295 | 시간 1118[s] | 손실 2.01
# | 에폭 2 |  반복 7201 / 9295 | 시간 1119[s] | 손실 2.01
# | 에폭 2 |  반복 7221 / 9295 | 시간 1121[s] | 손실 2.07
# | 에폭 2 |  반복 7241 / 9295 | 시간 1122[s] | 손실 2.05
# | 에폭 2 |  반복 7261 / 9295 | 시간 1124[s] | 손실 2.04
# | 에폭 2 |  반복 7281 / 9295 | 시간 1125[s] | 손실 2.04
# | 에폭 2 |  반복 7301 / 9295 | 시간 1126[s] | 손실 2.03
# | 에폭 2 |  반복 7321 / 9295 | 시간 1128[s] | 손실 2.02
# | 에폭 2 |  반복 7341 / 9295 | 시간 1129[s] | 손실 2.06
# | 에폭 2 |  반복 7361 / 9295 | 시간 1130[s] | 손실 2.05
# | 에폭 2 |  반복 7381 / 9295 | 시간 1132[s] | 손실 2.01
# | 에폭 2 |  반복 7401 / 9295 | 시간 1133[s] | 손실 2.09
# | 에폭 2 |  반복 7421 / 9295 | 시간 1134[s] | 손실 2.03
# | 에폭 2 |  반복 7441 / 9295 | 시간 1136[s] | 손실 2.05
# | 에폭 2 |  반복 7461 / 9295 | 시간 1137[s] | 손실 2.03
# | 에폭 2 |  반복 7481 / 9295 | 시간 1138[s] | 손실 2.03
# | 에폭 2 |  반복 7501 / 9295 | 시간 1140[s] | 손실 2.06
# | 에폭 2 |  반복 7521 / 9295 | 시간 1141[s] | 손실 2.03
# | 에폭 2 |  반복 7541 / 9295 | 시간 1143[s] | 손실 2.04
# | 에폭 2 |  반복 7561 / 9295 | 시간 1144[s] | 손실 2.06
# | 에폭 2 |  반복 7581 / 9295 | 시간 1145[s] | 손실 2.04
# | 에폭 2 |  반복 7601 / 9295 | 시간 1147[s] | 손실 2.01
# | 에폭 2 |  반복 7621 / 9295 | 시간 1148[s] | 손실 2.02
# | 에폭 2 |  반복 7641 / 9295 | 시간 1149[s] | 손실 2.02
# | 에폭 2 |  반복 7661 / 9295 | 시간 1151[s] | 손실 2.05
# | 에폭 2 |  반복 7681 / 9295 | 시간 1152[s] | 손실 2.06
# | 에폭 2 |  반복 7701 / 9295 | 시간 1153[s] | 손실 2.02
# | 에폭 2 |  반복 7721 / 9295 | 시간 1155[s] | 손실 2.05
# | 에폭 2 |  반복 7741 / 9295 | 시간 1156[s] | 손실 2.03
# | 에폭 2 |  반복 7761 / 9295 | 시간 1157[s] | 손실 2.04
# | 에폭 2 |  반복 7781 / 9295 | 시간 1159[s] | 손실 2.05
# | 에폭 2 |  반복 7801 / 9295 | 시간 1160[s] | 손실 2.04
# | 에폭 2 |  반복 7821 / 9295 | 시간 1162[s] | 손실 2.07
# | 에폭 2 |  반복 7841 / 9295 | 시간 1163[s] | 손실 2.01
# | 에폭 2 |  반복 7861 / 9295 | 시간 1164[s] | 손실 2.03
# | 에폭 2 |  반복 7881 / 9295 | 시간 1166[s] | 손실 2.03
# | 에폭 2 |  반복 7901 / 9295 | 시간 1167[s] | 손실 2.05
# | 에폭 2 |  반복 7921 / 9295 | 시간 1168[s] | 손실 2.03
# | 에폭 2 |  반복 7941 / 9295 | 시간 1170[s] | 손실 2.02
# | 에폭 2 |  반복 7961 / 9295 | 시간 1171[s] | 손실 2.04
# | 에폭 2 |  반복 7981 / 9295 | 시간 1172[s] | 손실 2.04
# | 에폭 2 |  반복 8001 / 9295 | 시간 1174[s] | 손실 2.02
# | 에폭 2 |  반복 8021 / 9295 | 시간 1175[s] | 손실 2.07
# | 에폭 2 |  반복 8041 / 9295 | 시간 1177[s] | 손실 2.04
# | 에폭 2 |  반복 8061 / 9295 | 시간 1178[s] | 손실 2.03
# | 에폭 2 |  반복 8081 / 9295 | 시간 1179[s] | 손실 2.06
# | 에폭 2 |  반복 8101 / 9295 | 시간 1181[s] | 손실 2.03
# | 에폭 2 |  반복 8121 / 9295 | 시간 1182[s] | 손실 2.02
# | 에폭 2 |  반복 8141 / 9295 | 시간 1183[s] | 손실 2.00
# | 에폭 2 |  반복 8161 / 9295 | 시간 1185[s] | 손실 2.02
# | 에폭 2 |  반복 8181 / 9295 | 시간 1186[s] | 손실 2.02
# | 에폭 2 |  반복 8201 / 9295 | 시간 1187[s] | 손실 2.03
# | 에폭 2 |  반복 8221 / 9295 | 시간 1189[s] | 손실 2.02
# | 에폭 2 |  반복 8241 / 9295 | 시간 1190[s] | 손실 2.03
# | 에폭 2 |  반복 8261 / 9295 | 시간 1191[s] | 손실 2.05
# | 에폭 2 |  반복 8281 / 9295 | 시간 1193[s] | 손실 2.01
# | 에폭 2 |  반복 8301 / 9295 | 시간 1194[s] | 손실 2.00
# | 에폭 2 |  반복 8321 / 9295 | 시간 1196[s] | 손실 2.06
# | 에폭 2 |  반복 8341 / 9295 | 시간 1197[s] | 손실 2.00
# | 에폭 2 |  반복 8361 / 9295 | 시간 1198[s] | 손실 2.04
# | 에폭 2 |  반복 8381 / 9295 | 시간 1200[s] | 손실 2.01
# | 에폭 2 |  반복 8401 / 9295 | 시간 1201[s] | 손실 2.02
# | 에폭 2 |  반복 8421 / 9295 | 시간 1202[s] | 손실 2.06
# | 에폭 2 |  반복 8441 / 9295 | 시간 1204[s] | 손실 2.03
# | 에폭 2 |  반복 8461 / 9295 | 시간 1205[s] | 손실 2.01
# | 에폭 2 |  반복 8481 / 9295 | 시간 1206[s] | 손실 1.99
# | 에폭 2 |  반복 8501 / 9295 | 시간 1208[s] | 손실 2.03
# | 에폭 2 |  반복 8521 / 9295 | 시간 1209[s] | 손실 2.06
# | 에폭 2 |  반복 8541 / 9295 | 시간 1210[s] | 손실 2.03
# | 에폭 2 |  반복 8561 / 9295 | 시간 1212[s] | 손실 2.01
# | 에폭 2 |  반복 8581 / 9295 | 시간 1213[s] | 손실 1.98
# | 에폭 2 |  반복 8601 / 9295 | 시간 1215[s] | 손실 2.00
# | 에폭 2 |  반복 8621 / 9295 | 시간 1216[s] | 손실 2.06
# | 에폭 2 |  반복 8641 / 9295 | 시간 1217[s] | 손실 2.06
# | 에폭 2 |  반복 8661 / 9295 | 시간 1219[s] | 손실 2.02
# | 에폭 2 |  반복 8681 / 9295 | 시간 1220[s] | 손실 2.02
# | 에폭 2 |  반복 8701 / 9295 | 시간 1221[s] | 손실 2.01
# | 에폭 2 |  반복 8721 / 9295 | 시간 1223[s] | 손실 2.02
# | 에폭 2 |  반복 8741 / 9295 | 시간 1224[s] | 손실 2.00
# | 에폭 2 |  반복 8761 / 9295 | 시간 1225[s] | 손실 2.05
# | 에폭 2 |  반복 8781 / 9295 | 시간 1227[s] | 손실 2.03
# | 에폭 2 |  반복 8801 / 9295 | 시간 1228[s] | 손실 2.05
# | 에폭 2 |  반복 8821 / 9295 | 시간 1230[s] | 손실 2.03
# | 에폭 2 |  반복 8841 / 9295 | 시간 1231[s] | 손실 2.03
# | 에폭 2 |  반복 8861 / 9295 | 시간 1232[s] | 손실 2.00
# | 에폭 2 |  반복 8881 / 9295 | 시간 1234[s] | 손실 2.00
# | 에폭 2 |  반복 8901 / 9295 | 시간 1235[s] | 손실 2.01
# | 에폭 2 |  반복 8921 / 9295 | 시간 1236[s] | 손실 2.06
# | 에폭 2 |  반복 8941 / 9295 | 시간 1238[s] | 손실 2.05
# | 에폭 2 |  반복 8961 / 9295 | 시간 1239[s] | 손실 2.01
# | 에폭 2 |  반복 8981 / 9295 | 시간 1240[s] | 손실 2.03
# | 에폭 2 |  반복 9001 / 9295 | 시간 1242[s] | 손실 2.02
# | 에폭 2 |  반복 9021 / 9295 | 시간 1243[s] | 손실 1.99
# | 에폭 2 |  반복 9041 / 9295 | 시간 1244[s] | 손실 2.05
# | 에폭 2 |  반복 9061 / 9295 | 시간 1246[s] | 손실 2.01
# | 에폭 2 |  반복 9081 / 9295 | 시간 1247[s] | 손실 2.02
# | 에폭 2 |  반복 9101 / 9295 | 시간 1249[s] | 손실 1.99
# | 에폭 2 |  반복 9121 / 9295 | 시간 1250[s] | 손실 2.00
# | 에폭 2 |  반복 9141 / 9295 | 시간 1251[s] | 손실 2.02
# | 에폭 2 |  반복 9161 / 9295 | 시간 1253[s] | 손실 2.03
# | 에폭 2 |  반복 9181 / 9295 | 시간 1254[s] | 손실 2.01
# | 에폭 2 |  반복 9201 / 9295 | 시간 1255[s] | 손실 2.05
# | 에폭 2 |  반복 9221 / 9295 | 시간 1257[s] | 손실 2.02
# | 에폭 2 |  반복 9241 / 9295 | 시간 1258[s] | 손실 2.02
# | 에폭 2 |  반복 9261 / 9295 | 시간 1259[s] | 손실 2.00
# | 에폭 2 |  반복 9281 / 9295 | 시간 1261[s] | 손실 2.00
# | 에폭 3 |  반복 1 / 9295 | 시간 1262[s] | 손실 2.02
# | 에폭 3 |  반복 21 / 9295 | 시간 1263[s] | 손실 2.00
# | 에폭 3 |  반복 41 / 9295 | 시간 1265[s] | 손실 1.94
# | 에폭 3 |  반복 61 / 9295 | 시간 1266[s] | 손실 1.91
# | 에폭 3 |  반복 81 / 9295 | 시간 1267[s] | 손실 1.92
# | 에폭 3 |  반복 101 / 9295 | 시간 1269[s] | 손실 1.95
# | 에폭 3 |  반복 121 / 9295 | 시간 1270[s] | 손실 1.95
# | 에폭 3 |  반복 141 / 9295 | 시간 1271[s] | 손실 1.93
# | 에폭 3 |  반복 161 / 9295 | 시간 1273[s] | 손실 1.94
# | 에폭 3 |  반복 181 / 9295 | 시간 1274[s] | 손실 1.94
# | 에폭 3 |  반복 201 / 9295 | 시간 1276[s] | 손실 1.94
# | 에폭 3 |  반복 221 / 9295 | 시간 1277[s] | 손실 1.95
# | 에폭 3 |  반복 241 / 9295 | 시간 1278[s] | 손실 1.95
# | 에폭 3 |  반복 261 / 9295 | 시간 1280[s] | 손실 1.91
# | 에폭 3 |  반복 281 / 9295 | 시간 1281[s] | 손실 1.97
# | 에폭 3 |  반복 301 / 9295 | 시간 1282[s] | 손실 1.95
# | 에폭 3 |  반복 321 / 9295 | 시간 1284[s] | 손실 1.92
# | 에폭 3 |  반복 341 / 9295 | 시간 1285[s] | 손실 1.92
# | 에폭 3 |  반복 361 / 9295 | 시간 1286[s] | 손실 1.96
# | 에폭 3 |  반복 381 / 9295 | 시간 1288[s] | 손실 1.95
# | 에폭 3 |  반복 401 / 9295 | 시간 1289[s] | 손실 1.95
# | 에폭 3 |  반복 421 / 9295 | 시간 1290[s] | 손실 1.94
# | 에폭 3 |  반복 441 / 9295 | 시간 1292[s] | 손실 1.93
# | 에폭 3 |  반복 461 / 9295 | 시간 1293[s] | 손실 1.95
# | 에폭 3 |  반복 481 / 9295 | 시간 1295[s] | 손실 1.95
# | 에폭 3 |  반복 501 / 9295 | 시간 1296[s] | 손실 1.94
# | 에폭 3 |  반복 521 / 9295 | 시간 1297[s] | 손실 1.94
# | 에폭 3 |  반복 541 / 9295 | 시간 1299[s] | 손실 1.97
# | 에폭 3 |  반복 561 / 9295 | 시간 1300[s] | 손실 1.96
# | 에폭 3 |  반복 581 / 9295 | 시간 1301[s] | 손실 1.93
# | 에폭 3 |  반복 601 / 9295 | 시간 1303[s] | 손실 1.93
# | 에폭 3 |  반복 621 / 9295 | 시간 1304[s] | 손실 1.95
# | 에폭 3 |  반복 641 / 9295 | 시간 1305[s] | 손실 1.92
# | 에폭 3 |  반복 661 / 9295 | 시간 1307[s] | 손실 1.96
# | 에폭 3 |  반복 681 / 9295 | 시간 1308[s] | 손실 1.97
# | 에폭 3 |  반복 701 / 9295 | 시간 1310[s] | 손실 2.01
# | 에폭 3 |  반복 721 / 9295 | 시간 1311[s] | 손실 1.92
# | 에폭 3 |  반복 741 / 9295 | 시간 1312[s] | 손실 2.01
# | 에폭 3 |  반복 761 / 9295 | 시간 1314[s] | 손실 1.94
# | 에폭 3 |  반복 781 / 9295 | 시간 1315[s] | 손실 1.96
# | 에폭 3 |  반복 801 / 9295 | 시간 1316[s] | 손실 1.94
# | 에폭 3 |  반복 821 / 9295 | 시간 1318[s] | 손실 1.97
# | 에폭 3 |  반복 841 / 9295 | 시간 1319[s] | 손실 1.97
# | 에폭 3 |  반복 861 / 9295 | 시간 1320[s] | 손실 1.95
# | 에폭 3 |  반복 881 / 9295 | 시간 1322[s] | 손실 1.94
# | 에폭 3 |  반복 901 / 9295 | 시간 1323[s] | 손실 1.97
# | 에폭 3 |  반복 921 / 9295 | 시간 1324[s] | 손실 1.97
# | 에폭 3 |  반복 941 / 9295 | 시간 1326[s] | 손실 1.93
# | 에폭 3 |  반복 961 / 9295 | 시간 1327[s] | 손실 1.94
# | 에폭 3 |  반복 981 / 9295 | 시간 1329[s] | 손실 1.93
# | 에폭 3 |  반복 1001 / 9295 | 시간 1330[s] | 손실 1.95
# | 에폭 3 |  반복 1021 / 9295 | 시간 1331[s] | 손실 1.95
# | 에폭 3 |  반복 1041 / 9295 | 시간 1333[s] | 손실 1.95
# | 에폭 3 |  반복 1061 / 9295 | 시간 1334[s] | 손실 1.98
# | 에폭 3 |  반복 1081 / 9295 | 시간 1335[s] | 손실 1.96
# | 에폭 3 |  반복 1101 / 9295 | 시간 1337[s] | 손실 1.98
# | 에폭 3 |  반복 1121 / 9295 | 시간 1338[s] | 손실 1.92
# | 에폭 3 |  반복 1141 / 9295 | 시간 1339[s] | 손실 1.93
# | 에폭 3 |  반복 1161 / 9295 | 시간 1341[s] | 손실 1.98
# | 에폭 3 |  반복 1181 / 9295 | 시간 1342[s] | 손실 1.95
# | 에폭 3 |  반복 1201 / 9295 | 시간 1343[s] | 손실 1.95
# | 에폭 3 |  반복 1221 / 9295 | 시간 1345[s] | 손실 1.94
# | 에폭 3 |  반복 1241 / 9295 | 시간 1346[s] | 손실 1.98
# | 에폭 3 |  반복 1261 / 9295 | 시간 1348[s] | 손실 1.93
# | 에폭 3 |  반복 1281 / 9295 | 시간 1349[s] | 손실 1.92
# | 에폭 3 |  반복 1301 / 9295 | 시간 1350[s] | 손실 1.96
# | 에폭 3 |  반복 1321 / 9295 | 시간 1352[s] | 손실 1.94
# | 에폭 3 |  반복 1341 / 9295 | 시간 1353[s] | 손실 1.94
# | 에폭 3 |  반복 1361 / 9295 | 시간 1354[s] | 손실 1.93
# | 에폭 3 |  반복 1381 / 9295 | 시간 1356[s] | 손실 1.94
# | 에폭 3 |  반복 1401 / 9295 | 시간 1357[s] | 손실 1.96
# | 에폭 3 |  반복 1421 / 9295 | 시간 1358[s] | 손실 1.92
# | 에폭 3 |  반복 1441 / 9295 | 시간 1360[s] | 손실 1.94
# | 에폭 3 |  반복 1461 / 9295 | 시간 1361[s] | 손실 1.91
# | 에폭 3 |  반복 1481 / 9295 | 시간 1362[s] | 손실 1.93
# | 에폭 3 |  반복 1501 / 9295 | 시간 1364[s] | 손실 1.95
# | 에폭 3 |  반복 1521 / 9295 | 시간 1365[s] | 손실 1.93
# | 에폭 3 |  반복 1541 / 9295 | 시간 1367[s] | 손실 1.89
# | 에폭 3 |  반복 1561 / 9295 | 시간 1368[s] | 손실 1.93
# | 에폭 3 |  반복 1581 / 9295 | 시간 1369[s] | 손실 1.93
# | 에폭 3 |  반복 1601 / 9295 | 시간 1371[s] | 손실 1.93
# | 에폭 3 |  반복 1621 / 9295 | 시간 1372[s] | 손실 1.95
# | 에폭 3 |  반복 1641 / 9295 | 시간 1373[s] | 손실 1.96
# | 에폭 3 |  반복 1661 / 9295 | 시간 1375[s] | 손실 1.93
# | 에폭 3 |  반복 1681 / 9295 | 시간 1376[s] | 손실 1.94
# | 에폭 3 |  반복 1701 / 9295 | 시간 1377[s] | 손실 1.93
# | 에폭 3 |  반복 1721 / 9295 | 시간 1379[s] | 손실 1.93
# | 에폭 3 |  반복 1741 / 9295 | 시간 1380[s] | 손실 1.91
# | 에폭 3 |  반복 1761 / 9295 | 시간 1382[s] | 손실 1.93
# | 에폭 3 |  반복 1781 / 9295 | 시간 1383[s] | 손실 1.91
# ...
# | 에폭 10 |  반복 3341 / 9295 | 시간 5955[s] | 손실 1.44
# | 에폭 10 |  반복 3361 / 9295 | 시간 5956[s] | 손실 1.41
# | 에폭 10 |  반복 3381 / 9295 | 시간 5957[s] | 손실 1.44
# | 에폭 10 |  반복 3401 / 9295 | 시간 5959[s] | 손실 1.43
# | 에폭 10 |  반복 3421 / 9295 | 시간 5960[s] | 손실 1.46
# | 에폭 10 |  반복 3441 / 9295 | 시간 5961[s] | 손실 1.43
# | 에폭 10 |  반복 3461 / 9295 | 시간 5963[s] | 손실 1.42
# | 에폭 10 |  반복 3481 / 9295 | 시간 5964[s] | 손실 1.44
# | 에폭 10 |  반복 3501 / 9295 | 시간 5966[s] | 손실 1.46
# | 에폭 10 |  반복 3521 / 9295 | 시간 5967[s] | 손실 1.42
# | 에폭 10 |  반복 3541 / 9295 | 시간 5968[s] | 손실 1.43
# | 에폭 10 |  반복 3561 / 9295 | 시간 5970[s] | 손실 1.45
# | 에폭 10 |  반복 3581 / 9295 | 시간 5971[s] | 손실 1.41
# | 에폭 10 |  반복 3601 / 9295 | 시간 5973[s] | 손실 1.44
# | 에폭 10 |  반복 3621 / 9295 | 시간 5974[s] | 손실 1.44
# | 에폭 10 |  반복 3641 / 9295 | 시간 5975[s] | 손실 1.44
# | 에폭 10 |  반복 3661 / 9295 | 시간 5977[s] | 손실 1.43
# | 에폭 10 |  반복 3681 / 9295 | 시간 5978[s] | 손실 1.42
# | 에폭 10 |  반복 3701 / 9295 | 시간 5979[s] | 손실 1.41
# | 에폭 10 |  반복 3721 / 9295 | 시간 5981[s] | 손실 1.42
# | 에폭 10 |  반복 3741 / 9295 | 시간 5982[s] | 손실 1.44
# | 에폭 10 |  반복 3761 / 9295 | 시간 5984[s] | 손실 1.44
# | 에폭 10 |  반복 3781 / 9295 | 시간 5985[s] | 손실 1.40
# | 에폭 10 |  반복 3801 / 9295 | 시간 5986[s] | 손실 1.41
# | 에폭 10 |  반복 3821 / 9295 | 시간 5988[s] | 손실 1.48
# | 에폭 10 |  반복 3841 / 9295 | 시간 5989[s] | 손실 1.43
# | 에폭 10 |  반복 3861 / 9295 | 시간 5990[s] | 손실 1.41
# | 에폭 10 |  반복 3881 / 9295 | 시간 5992[s] | 손실 1.41
# | 에폭 10 |  반복 3901 / 9295 | 시간 5993[s] | 손실 1.47
# | 에폭 10 |  반복 3921 / 9295 | 시간 5995[s] | 손실 1.47
# | 에폭 10 |  반복 3941 / 9295 | 시간 5996[s] | 손실 1.44
# | 에폭 10 |  반복 3961 / 9295 | 시간 5997[s] | 손실 1.44
# | 에폭 10 |  반복 3981 / 9295 | 시간 5999[s] | 손실 1.46
# | 에폭 10 |  반복 4001 / 9295 | 시간 6000[s] | 손실 1.41
# | 에폭 10 |  반복 4021 / 9295 | 시간 6002[s] | 손실 1.42
# | 에폭 10 |  반복 4041 / 9295 | 시간 6003[s] | 손실 1.45
# | 에폭 10 |  반복 4061 / 9295 | 시간 6004[s] | 손실 1.46
# | 에폭 10 |  반복 4081 / 9295 | 시간 6006[s] | 손실 1.50
# | 에폭 10 |  반복 4101 / 9295 | 시간 6007[s] | 손실 1.47
# | 에폭 10 |  반복 4121 / 9295 | 시간 6008[s] | 손실 1.42
# | 에폭 10 |  반복 4141 / 9295 | 시간 6010[s] | 손실 1.47
# | 에폭 10 |  반복 4161 / 9295 | 시간 6011[s] | 손실 1.42
# | 에폭 10 |  반복 4181 / 9295 | 시간 6013[s] | 손실 1.41
# | 에폭 10 |  반복 4201 / 9295 | 시간 6014[s] | 손실 1.44
# | 에폭 10 |  반복 4221 / 9295 | 시간 6015[s] | 손실 1.44
# | 에폭 10 |  반복 4241 / 9295 | 시간 6017[s] | 손실 1.45
# | 에폭 10 |  반복 4261 / 9295 | 시간 6018[s] | 손실 1.45
# | 에폭 10 |  반복 4281 / 9295 | 시간 6019[s] | 손실 1.42
# | 에폭 10 |  반복 4301 / 9295 | 시간 6021[s] | 손실 1.38
# | 에폭 10 |  반복 4321 / 9295 | 시간 6022[s] | 손실 1.47
# | 에폭 10 |  반복 4341 / 9295 | 시간 6024[s] | 손실 1.40
# | 에폭 10 |  반복 4361 / 9295 | 시간 6025[s] | 손실 1.38
# | 에폭 10 |  반복 4381 / 9295 | 시간 6026[s] | 손실 1.45
# | 에폭 10 |  반복 4401 / 9295 | 시간 6028[s] | 손실 1.44
# | 에폭 10 |  반복 4421 / 9295 | 시간 6029[s] | 손실 1.46
# | 에폭 10 |  반복 4441 / 9295 | 시간 6030[s] | 손실 1.41
# | 에폭 10 |  반복 4461 / 9295 | 시간 6032[s] | 손실 1.43
# | 에폭 10 |  반복 4481 / 9295 | 시간 6033[s] | 손실 1.44
# | 에폭 10 |  반복 4501 / 9295 | 시간 6035[s] | 손실 1.47
# | 에폭 10 |  반복 4521 / 9295 | 시간 6036[s] | 손실 1.44
# | 에폭 10 |  반복 4541 / 9295 | 시간 6037[s] | 손실 1.44
# | 에폭 10 |  반복 4561 / 9295 | 시간 6039[s] | 손실 1.43
# | 에폭 10 |  반복 4581 / 9295 | 시간 6040[s] | 손실 1.45
# | 에폭 10 |  반복 4601 / 9295 | 시간 6042[s] | 손실 1.44
# | 에폭 10 |  반복 4621 / 9295 | 시간 6043[s] | 손실 1.47
# | 에폭 10 |  반복 4641 / 9295 | 시간 6044[s] | 손실 1.44
# | 에폭 10 |  반복 4661 / 9295 | 시간 6046[s] | 손실 1.41
# | 에폭 10 |  반복 4681 / 9295 | 시간 6047[s] | 손실 1.45
# | 에폭 10 |  반복 4701 / 9295 | 시간 6048[s] | 손실 1.43
# | 에폭 10 |  반복 4721 / 9295 | 시간 6050[s] | 손실 1.45
# | 에폭 10 |  반복 4741 / 9295 | 시간 6051[s] | 손실 1.47
# | 에폭 10 |  반복 4761 / 9295 | 시간 6053[s] | 손실 1.49
# | 에폭 10 |  반복 4781 / 9295 | 시간 6054[s] | 손실 1.45
# | 에폭 10 |  반복 4801 / 9295 | 시간 6055[s] | 손실 1.44
# | 에폭 10 |  반복 4821 / 9295 | 시간 6057[s] | 손실 1.45
# | 에폭 10 |  반복 4841 / 9295 | 시간 6058[s] | 손실 1.45
# | 에폭 10 |  반복 4861 / 9295 | 시간 6059[s] | 손실 1.45
# | 에폭 10 |  반복 4881 / 9295 | 시간 6061[s] | 손실 1.41
# | 에폭 10 |  반복 4901 / 9295 | 시간 6062[s] | 손실 1.41
# | 에폭 10 |  반복 4921 / 9295 | 시간 6064[s] | 손실 1.43
# | 에폭 10 |  반복 4941 / 9295 | 시간 6065[s] | 손실 1.44
# | 에폭 10 |  반복 4961 / 9295 | 시간 6066[s] | 손실 1.46
# | 에폭 10 |  반복 4981 / 9295 | 시간 6068[s] | 손실 1.43
# | 에폭 10 |  반복 5001 / 9295 | 시간 6069[s] | 손실 1.42
# | 에폭 10 |  반복 5021 / 9295 | 시간 6071[s] | 손실 1.43
# | 에폭 10 |  반복 5041 / 9295 | 시간 6072[s] | 손실 1.42
# | 에폭 10 |  반복 5061 / 9295 | 시간 6073[s] | 손실 1.42
# | 에폭 10 |  반복 5081 / 9295 | 시간 6075[s] | 손실 1.42
# | 에폭 10 |  반복 5101 / 9295 | 시간 6076[s] | 손실 1.42
# | 에폭 10 |  반복 5121 / 9295 | 시간 6077[s] | 손실 1.44
# | 에폭 10 |  반복 5141 / 9295 | 시간 6079[s] | 손실 1.43
# | 에폭 10 |  반복 5161 / 9295 | 시간 6080[s] | 손실 1.46
# | 에폭 10 |  반복 5181 / 9295 | 시간 6082[s] | 손실 1.47
# | 에폭 10 |  반복 5201 / 9295 | 시간 6083[s] | 손실 1.46
# | 에폭 10 |  반복 5221 / 9295 | 시간 6084[s] | 손실 1.42
# | 에폭 10 |  반복 5241 / 9295 | 시간 6086[s] | 손실 1.46
# | 에폭 10 |  반복 5261 / 9295 | 시간 6087[s] | 손실 1.45
# | 에폭 10 |  반복 5281 / 9295 | 시간 6088[s] | 손실 1.44
# | 에폭 10 |  반복 5301 / 9295 | 시간 6090[s] | 손실 1.45
# | 에폭 10 |  반복 5321 / 9295 | 시간 6091[s] | 손실 1.47
# | 에폭 10 |  반복 5341 / 9295 | 시간 6093[s] | 손실 1.41
# | 에폭 10 |  반복 5361 / 9295 | 시간 6094[s] | 손실 1.44
# | 에폭 10 |  반복 5381 / 9295 | 시간 6095[s] | 손실 1.45
# | 에폭 10 |  반복 5401 / 9295 | 시간 6097[s] | 손실 1.40
# | 에폭 10 |  반복 5421 / 9295 | 시간 6098[s] | 손실 1.45
# | 에폭 10 |  반복 5441 / 9295 | 시간 6099[s] | 손실 1.43
# | 에폭 10 |  반복 5461 / 9295 | 시간 6101[s] | 손실 1.43
# | 에폭 10 |  반복 5481 / 9295 | 시간 6102[s] | 손실 1.40
# | 에폭 10 |  반복 5501 / 9295 | 시간 6104[s] | 손실 1.44
# | 에폭 10 |  반복 5521 / 9295 | 시간 6105[s] | 손실 1.45
# | 에폭 10 |  반복 5541 / 9295 | 시간 6106[s] | 손실 1.48
# | 에폭 10 |  반복 5561 / 9295 | 시간 6108[s] | 손실 1.42
# | 에폭 10 |  반복 5581 / 9295 | 시간 6109[s] | 손실 1.46
# | 에폭 10 |  반복 5601 / 9295 | 시간 6111[s] | 손실 1.41
# | 에폭 10 |  반복 5621 / 9295 | 시간 6112[s] | 손실 1.46
# | 에폭 10 |  반복 5641 / 9295 | 시간 6113[s] | 손실 1.46
# | 에폭 10 |  반복 5661 / 9295 | 시간 6115[s] | 손실 1.45
# | 에폭 10 |  반복 5681 / 9295 | 시간 6116[s] | 손실 1.44
# | 에폭 10 |  반복 5701 / 9295 | 시간 6117[s] | 손실 1.46
# | 에폭 10 |  반복 5721 / 9295 | 시간 6119[s] | 손실 1.44
# | 에폭 10 |  반복 5741 / 9295 | 시간 6120[s] | 손실 1.44
# | 에폭 10 |  반복 5761 / 9295 | 시간 6122[s] | 손실 1.44
# | 에폭 10 |  반복 5781 / 9295 | 시간 6123[s] | 손실 1.42
# | 에폭 10 |  반복 5801 / 9295 | 시간 6124[s] | 손실 1.46
# | 에폭 10 |  반복 5821 / 9295 | 시간 6126[s] | 손실 1.43
# | 에폭 10 |  반복 5841 / 9295 | 시간 6127[s] | 손실 1.50
# | 에폭 10 |  반복 5861 / 9295 | 시간 6128[s] | 손실 1.42
# | 에폭 10 |  반복 5881 / 9295 | 시간 6130[s] | 손실 1.43
# | 에폭 10 |  반복 5901 / 9295 | 시간 6131[s] | 손실 1.46
# | 에폭 10 |  반복 5921 / 9295 | 시간 6133[s] | 손실 1.45
# | 에폭 10 |  반복 5941 / 9295 | 시간 6134[s] | 손실 1.43
# | 에폭 10 |  반복 5961 / 9295 | 시간 6135[s] | 손실 1.44
# | 에폭 10 |  반복 5981 / 9295 | 시간 6137[s] | 손실 1.42
# | 에폭 10 |  반복 6001 / 9295 | 시간 6138[s] | 손실 1.41
# | 에폭 10 |  반복 6021 / 9295 | 시간 6140[s] | 손실 1.47
# | 에폭 10 |  반복 6041 / 9295 | 시간 6141[s] | 손실 1.46
# | 에폭 10 |  반복 6061 / 9295 | 시간 6142[s] | 손실 1.47
# | 에폭 10 |  반복 6081 / 9295 | 시간 6144[s] | 손실 1.46
# | 에폭 10 |  반복 6101 / 9295 | 시간 6145[s] | 손실 1.42
# | 에폭 10 |  반복 6121 / 9295 | 시간 6146[s] | 손실 1.46
# | 에폭 10 |  반복 6141 / 9295 | 시간 6148[s] | 손실 1.50
# | 에폭 10 |  반복 6161 / 9295 | 시간 6149[s] | 손실 1.43
# | 에폭 10 |  반복 6181 / 9295 | 시간 6151[s] | 손실 1.44
# | 에폭 10 |  반복 6201 / 9295 | 시간 6152[s] | 손실 1.43
# | 에폭 10 |  반복 6221 / 9295 | 시간 6153[s] | 손실 1.44
# | 에폭 10 |  반복 6241 / 9295 | 시간 6155[s] | 손실 1.45
# | 에폭 10 |  반복 6261 / 9295 | 시간 6156[s] | 손실 1.40
# | 에폭 10 |  반복 6281 / 9295 | 시간 6158[s] | 손실 1.43
# | 에폭 10 |  반복 6301 / 9295 | 시간 6159[s] | 손실 1.46
# | 에폭 10 |  반복 6321 / 9295 | 시간 6160[s] | 손실 1.49
# | 에폭 10 |  반복 6341 / 9295 | 시간 6162[s] | 손실 1.41
# | 에폭 10 |  반복 6361 / 9295 | 시간 6163[s] | 손실 1.44
# | 에폭 10 |  반복 6381 / 9295 | 시간 6164[s] | 손실 1.44
# | 에폭 10 |  반복 6401 / 9295 | 시간 6166[s] | 손실 1.40
# | 에폭 10 |  반복 6421 / 9295 | 시간 6167[s] | 손실 1.43
# | 에폭 10 |  반복 6441 / 9295 | 시간 6169[s] | 손실 1.47
# | 에폭 10 |  반복 6461 / 9295 | 시간 6170[s] | 손실 1.47
# | 에폭 10 |  반복 6481 / 9295 | 시간 6171[s] | 손실 1.41
# | 에폭 10 |  반복 6501 / 9295 | 시간 6173[s] | 손실 1.46
# | 에폭 10 |  반복 6521 / 9295 | 시간 6174[s] | 손실 1.47
# | 에폭 10 |  반복 6541 / 9295 | 시간 6175[s] | 손실 1.39
# | 에폭 10 |  반복 6561 / 9295 | 시간 6177[s] | 손실 1.48
# | 에폭 10 |  반복 6581 / 9295 | 시간 6178[s] | 손실 1.44
# | 에폭 10 |  반복 6601 / 9295 | 시간 6180[s] | 손실 1.42
# | 에폭 10 |  반복 6621 / 9295 | 시간 6181[s] | 손실 1.43
# | 에폭 10 |  반복 6641 / 9295 | 시간 6182[s] | 손실 1.50
# | 에폭 10 |  반복 6661 / 9295 | 시간 6184[s] | 손실 1.43
# | 에폭 10 |  반복 6681 / 9295 | 시간 6185[s] | 손실 1.42
# | 에폭 10 |  반복 6701 / 9295 | 시간 6186[s] | 손실 1.44
# | 에폭 10 |  반복 6721 / 9295 | 시간 6188[s] | 손실 1.44
# | 에폭 10 |  반복 6741 / 9295 | 시간 6189[s] | 손실 1.47
# | 에폭 10 |  반복 6761 / 9295 | 시간 6191[s] | 손실 1.43
# | 에폭 10 |  반복 6781 / 9295 | 시간 6192[s] | 손실 1.44
# | 에폭 10 |  반복 6801 / 9295 | 시간 6193[s] | 손실 1.44
# | 에폭 10 |  반복 6821 / 9295 | 시간 6195[s] | 손실 1.45
# | 에폭 10 |  반복 6841 / 9295 | 시간 6196[s] | 손실 1.46
# | 에폭 10 |  반복 6861 / 9295 | 시간 6198[s] | 손실 1.45
# | 에폭 10 |  반복 6881 / 9295 | 시간 6199[s] | 손실 1.48
# | 에폭 10 |  반복 6901 / 9295 | 시간 6200[s] | 손실 1.46
# | 에폭 10 |  반복 6921 / 9295 | 시간 6202[s] | 손실 1.46
# | 에폭 10 |  반복 6941 / 9295 | 시간 6203[s] | 손실 1.44
# | 에폭 10 |  반복 6961 / 9295 | 시간 6204[s] | 손실 1.45
# | 에폭 10 |  반복 6981 / 9295 | 시간 6206[s] | 손실 1.45
# | 에폭 10 |  반복 7001 / 9295 | 시간 6207[s] | 손실 1.44
# | 에폭 10 |  반복 7021 / 9295 | 시간 6209[s] | 손실 1.46
# | 에폭 10 |  반복 7041 / 9295 | 시간 6210[s] | 손실 1.48
# | 에폭 10 |  반복 7061 / 9295 | 시간 6211[s] | 손실 1.44
# | 에폭 10 |  반복 7081 / 9295 | 시간 6213[s] | 손실 1.41
# | 에폭 10 |  반복 7101 / 9295 | 시간 6214[s] | 손실 1.46
# | 에폭 10 |  반복 7121 / 9295 | 시간 6215[s] | 손실 1.44
# | 에폭 10 |  반복 7141 / 9295 | 시간 6217[s] | 손실 1.47
# | 에폭 10 |  반복 7161 / 9295 | 시간 6218[s] | 손실 1.44
# | 에폭 10 |  반복 7181 / 9295 | 시간 6220[s] | 손실 1.44
# | 에폭 10 |  반복 7201 / 9295 | 시간 6221[s] | 손실 1.45
# | 에폭 10 |  반복 7221 / 9295 | 시간 6222[s] | 손실 1.48
# | 에폭 10 |  반복 7241 / 9295 | 시간 6224[s] | 손실 1.46
# | 에폭 10 |  반복 7261 / 9295 | 시간 6225[s] | 손실 1.44
# | 에폭 10 |  반복 7281 / 9295 | 시간 6227[s] | 손실 1.42
# | 에폭 10 |  반복 7301 / 9295 | 시간 6228[s] | 손실 1.44
# | 에폭 10 |  반복 7321 / 9295 | 시간 6229[s] | 손실 1.45
# | 에폭 10 |  반복 7341 / 9295 | 시간 6231[s] | 손실 1.46
# | 에폭 10 |  반복 7361 / 9295 | 시간 6232[s] | 손실 1.46
# | 에폭 10 |  반복 7381 / 9295 | 시간 6233[s] | 손실 1.42
# | 에폭 10 |  반복 7401 / 9295 | 시간 6235[s] | 손실 1.49
# | 에폭 10 |  반복 7421 / 9295 | 시간 6236[s] | 손실 1.44
# | 에폭 10 |  반복 7441 / 9295 | 시간 6238[s] | 손실 1.45
# | 에폭 10 |  반복 7461 / 9295 | 시간 6239[s] | 손실 1.47
# | 에폭 10 |  반복 7481 / 9295 | 시간 6240[s] | 손실 1.47
# | 에폭 10 |  반복 7501 / 9295 | 시간 6242[s] | 손실 1.41
# | 에폭 10 |  반복 7521 / 9295 | 시간 6243[s] | 손실 1.47
# | 에폭 10 |  반복 7541 / 9295 | 시간 6244[s] | 손실 1.43
# | 에폭 10 |  반복 7561 / 9295 | 시간 6246[s] | 손실 1.44
# | 에폭 10 |  반복 7581 / 9295 | 시간 6247[s] | 손실 1.47
# | 에폭 10 |  반복 7601 / 9295 | 시간 6249[s] | 손실 1.42
# | 에폭 10 |  반복 7621 / 9295 | 시간 6250[s] | 손실 1.45
# | 에폭 10 |  반복 7641 / 9295 | 시간 6251[s] | 손실 1.49
# | 에폭 10 |  반복 7661 / 9295 | 시간 6253[s] | 손실 1.43
# | 에폭 10 |  반복 7681 / 9295 | 시간 6254[s] | 손실 1.44
# | 에폭 10 |  반복 7701 / 9295 | 시간 6256[s] | 손실 1.46
# | 에폭 10 |  반복 7721 / 9295 | 시간 6257[s] | 손실 1.46
# | 에폭 10 |  반복 7741 / 9295 | 시간 6258[s] | 손실 1.42
# | 에폭 10 |  반복 7761 / 9295 | 시간 6260[s] | 손실 1.45
# | 에폭 10 |  반복 7781 / 9295 | 시간 6261[s] | 손실 1.50
# | 에폭 10 |  반복 7801 / 9295 | 시간 6262[s] | 손실 1.47
# | 에폭 10 |  반복 7821 / 9295 | 시간 6264[s] | 손실 1.47
# | 에폭 10 |  반복 7841 / 9295 | 시간 6265[s] | 손실 1.47
# | 에폭 10 |  반복 7861 / 9295 | 시간 6267[s] | 손실 1.48
# | 에폭 10 |  반복 7881 / 9295 | 시간 6268[s] | 손실 1.43
# | 에폭 10 |  반복 7901 / 9295 | 시간 6269[s] | 손실 1.45
# | 에폭 10 |  반복 7921 / 9295 | 시간 6271[s] | 손실 1.45
# | 에폭 10 |  반복 7941 / 9295 | 시간 6272[s] | 손실 1.44
# | 에폭 10 |  반복 7961 / 9295 | 시간 6273[s] | 손실 1.45
# | 에폭 10 |  반복 7981 / 9295 | 시간 6275[s] | 손실 1.51
# | 에폭 10 |  반복 8001 / 9295 | 시간 6276[s] | 손실 1.43
# | 에폭 10 |  반복 8021 / 9295 | 시간 6278[s] | 손실 1.46
# | 에폭 10 |  반복 8041 / 9295 | 시간 6279[s] | 손실 1.42
# | 에폭 10 |  반복 8061 / 9295 | 시간 6280[s] | 손실 1.44
# | 에폭 10 |  반복 8081 / 9295 | 시간 6282[s] | 손실 1.44
# | 에폭 10 |  반복 8101 / 9295 | 시간 6283[s] | 손실 1.48
# | 에폭 10 |  반복 8121 / 9295 | 시간 6285[s] | 손실 1.46
# | 에폭 10 |  반복 8141 / 9295 | 시간 6286[s] | 손실 1.45
# | 에폭 10 |  반복 8161 / 9295 | 시간 6287[s] | 손실 1.39
# | 에폭 10 |  반복 8181 / 9295 | 시간 6289[s] | 손실 1.49
# | 에폭 10 |  반복 8201 / 9295 | 시간 6290[s] | 손실 1.41
# | 에폭 10 |  반복 8221 / 9295 | 시간 6291[s] | 손실 1.45
# | 에폭 10 |  반복 8241 / 9295 | 시간 6293[s] | 손실 1.48
# | 에폭 10 |  반복 8261 / 9295 | 시간 6294[s] | 손실 1.41
# | 에폭 10 |  반복 8281 / 9295 | 시간 6296[s] | 손실 1.44
# | 에폭 10 |  반복 8301 / 9295 | 시간 6297[s] | 손실 1.44
# | 에폭 10 |  반복 8321 / 9295 | 시간 6298[s] | 손실 1.43
# | 에폭 10 |  반복 8341 / 9295 | 시간 6300[s] | 손실 1.45
# | 에폭 10 |  반복 8361 / 9295 | 시간 6301[s] | 손실 1.43
# | 에폭 10 |  반복 8381 / 9295 | 시간 6302[s] | 손실 1.45
# | 에폭 10 |  반복 8401 / 9295 | 시간 6304[s] | 손실 1.45
# | 에폭 10 |  반복 8421 / 9295 | 시간 6305[s] | 손실 1.47
# | 에폭 10 |  반복 8441 / 9295 | 시간 6307[s] | 손실 1.44
# | 에폭 10 |  반복 8461 / 9295 | 시간 6308[s] | 손실 1.43
# | 에폭 10 |  반복 8481 / 9295 | 시간 6309[s] | 손실 1.47
# | 에폭 10 |  반복 8501 / 9295 | 시간 6311[s] | 손실 1.44
# | 에폭 10 |  반복 8521 / 9295 | 시간 6312[s] | 손실 1.44
# | 에폭 10 |  반복 8541 / 9295 | 시간 6313[s] | 손실 1.46
# | 에폭 10 |  반복 8561 / 9295 | 시간 6315[s] | 손실 1.44
# | 에폭 10 |  반복 8581 / 9295 | 시간 6316[s] | 손실 1.49
# | 에폭 10 |  반복 8601 / 9295 | 시간 6318[s] | 손실 1.45
# | 에폭 10 |  반복 8621 / 9295 | 시간 6319[s] | 손실 1.41
# | 에폭 10 |  반복 8641 / 9295 | 시간 6320[s] | 손실 1.49
# | 에폭 10 |  반복 8661 / 9295 | 시간 6322[s] | 손실 1.45
# | 에폭 10 |  반복 8681 / 9295 | 시간 6323[s] | 손실 1.48
# | 에폭 10 |  반복 8701 / 9295 | 시간 6324[s] | 손실 1.45
# | 에폭 10 |  반복 8721 / 9295 | 시간 6326[s] | 손실 1.45
# | 에폭 10 |  반복 8741 / 9295 | 시간 6327[s] | 손실 1.45
# | 에폭 10 |  반복 8761 / 9295 | 시간 6328[s] | 손실 1.52
# | 에폭 10 |  반복 8781 / 9295 | 시간 6330[s] | 손실 1.42
# | 에폭 10 |  반복 8801 / 9295 | 시간 6331[s] | 손실 1.45
# | 에폭 10 |  반복 8821 / 9295 | 시간 6332[s] | 손실 1.43
# | 에폭 10 |  반복 8841 / 9295 | 시간 6334[s] | 손실 1.49
# | 에폭 10 |  반복 8861 / 9295 | 시간 6335[s] | 손실 1.48
# | 에폭 10 |  반복 8881 / 9295 | 시간 6337[s] | 손실 1.49
# | 에폭 10 |  반복 8901 / 9295 | 시간 6338[s] | 손실 1.47
# | 에폭 10 |  반복 8921 / 9295 | 시간 6339[s] | 손실 1.52
# | 에폭 10 |  반복 8941 / 9295 | 시간 6341[s] | 손실 1.47
# | 에폭 10 |  반복 8961 / 9295 | 시간 6342[s] | 손실 1.43
# | 에폭 10 |  반복 8981 / 9295 | 시간 6343[s] | 손실 1.48
# | 에폭 10 |  반복 9001 / 9295 | 시간 6345[s] | 손실 1.39
# | 에폭 10 |  반복 9021 / 9295 | 시간 6346[s] | 손실 1.44
# | 에폭 10 |  반복 9041 / 9295 | 시간 6347[s] | 손실 1.46
# | 에폭 10 |  반복 9061 / 9295 | 시간 6349[s] | 손실 1.43
# | 에폭 10 |  반복 9081 / 9295 | 시간 6350[s] | 손실 1.45
# | 에폭 10 |  반복 9101 / 9295 | 시간 6352[s] | 손실 1.51
# | 에폭 10 |  반복 9121 / 9295 | 시간 6353[s] | 손실 1.47
# | 에폭 10 |  반복 9141 / 9295 | 시간 6354[s] | 손실 1.46
# | 에폭 10 |  반복 9161 / 9295 | 시간 6356[s] | 손실 1.47
# | 에폭 10 |  반복 9181 / 9295 | 시간 6357[s] | 손실 1.45
# | 에폭 10 |  반복 9201 / 9295 | 시간 6359[s] | 손실 1.43
# | 에폭 10 |  반복 9221 / 9295 | 시간 6360[s] | 손실 1.47
# | 에폭 10 |  반복 9241 / 9295 | 시간 6361[s] | 손실 1.40
# | 에폭 10 |  반복 9261 / 9295 | 시간 6363[s] | 손실 1.45
# | 에폭 10 |  반복 9281 / 9295 | 시간 6364[s] | 손실 1.45
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49892 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49552 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 49892 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from common.util import most_similar, analogy
import pickle

pkl_file = 'cbow_params.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']
    
querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)
# Out:
# [query] you
#  we: 0.75341796875
#  i: 0.7041015625
#  your: 0.6669921875
#  they: 0.626953125
#  anybody: 0.60302734375
#
# [query] year
#  month: 0.85205078125
#  week: 0.783203125
#  summer: 0.73876953125
#  spring: 0.73876953125
#  decade: 0.70556640625
#
# [query] car
#  window: 0.63232421875
#  truck: 0.6044921875
#  luxury: 0.60302734375
#  auto: 0.57275390625
#  merkur: 0.5537109375
#
# [query] toyota
#  seita: 0.63818359375
#  coated: 0.6201171875
#  chevrolet: 0.60986328125
#  engines: 0.60400390625
#  honda: 0.6025390625

# %%
analogy('king', 'man', 'queen',  word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go',  word_to_id, id_to_word, word_vecs)
analogy('car', 'cars', 'child',  word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad',  word_to_id, id_to_word, word_vecs)
# Out:
# [analogy] king:man = queen:?
#  woman: 5.66796875
#  a.m: 4.9921875
#  mother: 4.890625
#  gene: 4.6328125
#  wife: 4.59375
#
# [analogy] take:took = go:?
#  eurodollars: 4.734375
#  're: 4.72265625
#  went: 4.52734375
#  were: 4.50390625
#  came: 4.29296875
#
# [analogy] car:cars = child:?
#  a.m: 5.91796875
#  rape: 5.41796875
#  children: 5.37109375
#  bond-equivalent: 4.87890625
#  version: 4.76953125
#
# [analogy] good:better = bad:?
#  more: 5.8515625
#  rather: 5.55859375
#  less: 5.55859375
#  greater: 4.5546875
#  worse: 3.91015625
